# %% [markdown]
# <a href="https://www.kaggle.com/code/thanushanth/using-kuhar?scriptVersionId=201931307" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#Necessary Imports
import os
import logging
import inspect 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle
from torch import nn
import torch
import subprocess
from torch.utils.data import Dataset, DataLoader
import math
import time
import seaborn as sns
import matplotlib as mpl
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
import shutil
import random
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score,confusion_matrix
from sklearn.decomposition import PCA
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Define Constants

# %%
LOG_LEVEL = "INFO" # Adjust this to "DEBUG", "INFO", "WARNING" or "ERROR"

activity_id_mapping = {
    0 : "Stand",
    1 : "Sit",
    2 : "Talk-sit",
    3 : "Talk-stand",
    4 : "Stand-sit",
    5 : "Lay",
    6 : "Lay-stand",
    7 : "Pick",
    8 : "Jump",
    9 : "Push-up",
    10 : "Sit-up",
    11 : "Walk",
    12 : "Walk-backward",
    13 : "Walk-circle",
    14 : "Run",
    15 : "Stair-up",
    16 : "Stair-down",
    17 : "Table-tennis"
}

columns = ["activityID", "subjectID", 
               "acc_x", "acc_y", "acc_z", 
               "gyro_x", "gyro_y", "gyro_z", 
               "ori_x", "ori_y", "ori_z"]

EPOCH_BATCH_COUNT = 50
EPOCHS = 100
BATCH_SIZE = 32
IMU_FEATURE_COUNT = 24
CLASSES = 9
LEARNING_RATE = 0.001 # change learning rate 

BEST_ACCURACY = 0.0
BEST_LOSS = 1000

MAX_SAVED_MODELS = 4   # Maximum number of models to keep

# %% [markdown]
# # Genarate logs

# %%
# Map log level strings to logging constants
log_levels = {
    "DEBUG": logging.DEBUG,
    "INFO": logging.INFO,
    "WARNING": logging.WARNING,
    "ERROR": logging.ERROR
}
set_log_level = log_levels.get(LOG_LEVEL, logging.INFO)  # Default to INFO if an unrecognized level is given

# Configure the logging format and level
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=set_log_level,
    datefmt="%Y-%m-%d %H:%M:%S"
)

def log_message(level, message, block=None, log_title="", caller_frame=None):
    """
    Logs a message with a specific logging level and additional details.
    
    Args:
        level (str): Logging level ('DEBUG', 'INFO', 'WARNING', 'ERROR').
        message (str): The message to log.
        block (str, optional): Additional block/section name for context.
        log_title (str): Title to specify log type.
        caller_frame (frame, optional): Frame object of the calling function.
    """
    # Get the calling function's details for context
    line_number = caller_frame.f_lineno if caller_frame else "N/A"
    function_name = caller_frame.f_code.co_name if caller_frame else "N/A"

    # Format log title and line number to a fixed width
    formatted_title = log_title.ljust(7)  # Pad log title to 7 characters
    formatted_line = f"Line {line_number}".ljust(8)  # Pad line info to 8 characters

    # Format the log with extra details
    # log_msg = f"{formatted_title} | {formatted_line} | {function_name} | {message}"
    log_msg = f"{formatted_title} | {formatted_line} | {message}"
    if block:
        log_msg += f" - Block: {block}"

    # Check if the log level should print based on the configured log level
    should_print = log_levels[level.upper()] >= set_log_level

    if should_print:
        print(log_msg)  # Print the message if it meets or exceeds the log level

    # Log the message based on the specified level
    if level.upper() == "DEBUG":
        logging.debug(log_msg)
    elif level.upper() == "INFO":
        logging.info(log_msg)
    elif level.upper() == "WARNING":
        logging.warning(log_msg)
    elif level.upper() == "ERROR":
        logging.error(log_msg)
    else:
        logging.info("Unknown log level specified.")

# Shortcut functions for different levels
def print_log(message, block=None):
    caller_frame = inspect.currentframe().f_back
    log_message("INFO", message, block, log_title="INFO", caller_frame=caller_frame)

def debug_log(message, block=None):
    caller_frame = inspect.currentframe().f_back
    log_message("DEBUG", message, block, log_title="DEBUG", caller_frame=caller_frame)

def warn_log(message, block=None):
    caller_frame = inspect.currentframe().f_back
    log_message("WARNING", message, block, log_title="WARNING", caller_frame=caller_frame)

def error_log(message, block=None):
    caller_frame = inspect.currentframe().f_back
    log_message("ERROR", message, block, log_title="ERROR", caller_frame=caller_frame)

# %%
# The example usage of logs
print_log("Training started", block="Training Phase")
debug_log("Loaded 500 records", block="Data Loading")
warn_log("Missing values detected", block="Data Validation")
error_log("Failed to save model", block="Model Saving")
# Out:
# INFO    | Line 2   | Training started - Block: Training Phase
# WARNING | Line 4   | Missing values detected - Block: Data Validation
# ERROR   | Line 5   | Failed to save model - Block: Model Saving

# %% [markdown]
# # Clear Working Directory

# %%
import os
import shutil


def clear_working_directory():
    # Define the directory to clear
    directory_to_clear = '/kaggle/working/'

    # Iterate through all files and directories in the specified directory
    for filename in os.listdir(directory_to_clear):
        file_path = os.path.join(directory_to_clear, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)  # Remove the file or symbolic link
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Remove the directory and its contents
            print_log(f"Removed: {file_path}")  # Optional: Print the removed file or directory
        except Exception as e:
            error_log(f"Failed to remove {file_path}. Reason: {e}")

# %%
clear_working_directory()
# Out:
# INFO    | Line 17  | Removed: /kaggle/working/__notebook__.ipynb

# %% [markdown]
# # Preprocessing Data

# %%
#Reading data:

df = pd.read_csv("/kaggle/input/kuhar/3.Time_domain_subsamples/KU-HAR_time_domain_subsamples_20750x300.csv",header=None)
dff = df.values
signals = dff[:, 0: 1800] #These are the time-domian subsamples (signals) 
signals = np.array(signals, dtype=np.float32)
labels = dff[:, 1800] #These are their associated class labels (signals)

print_log(f"signals shape: {signals.shape} and labels shape: {labels.shape}")
# Out:
# INFO    | Line 9   | signals shape: (20750, 1800) and labels shape: (20750,)

# %%
# Reshape signals into 300 samples per axis for each sensor type (acc, gyro, orientation)
# For accelerometer data (X, Y, Z axis)
acc_x = signals[:, :300]
acc_y = signals[:, 300:600]
acc_z = signals[:, 600:900]
gyro_x = signals[:, 900:1200]
gyro_y = signals[:, 1200:1500]
gyro_z = signals[:, 1500:1800]

# Create a list to hold all rows of data
data_rows = []

# Loop over each activity ID and create rows for each sample and axis
for i in range(len(labels)):
    activity_id = labels[i]
    
    # For each of the 300 samples, create a row with each sensor axis value
    for sample in range(300):
        data_rows.append({"activityID": int(activity_id), 
                          "acc_x": acc_x[i, sample],
                         "acc_y" : acc_y[i, sample],
                         "acc_z" : acc_z[i, sample],
                         "gyro_x" : gyro_x[i, sample],
                         "gyro_y" : gyro_y[i, sample],
                         "gyro_z" : gyro_z[i, sample]})

# Create a DataFrame from the expanded data
new_df = pd.DataFrame(data_rows)
print_log("The basic new dataframe is genarated")
new_df
# Out:
# INFO    | Line 29  | The basic new dataframe is genarated
#          activityID     acc_x     acc_y     acc_z    gyro_x    gyro_y  \
# 0                 0  0.004231  0.005034 -0.020325 -0.000043  0.012474
# 1                 0 -0.000280  0.011153 -0.022526 -0.000816  0.010088
# 2                 0 -0.013906  0.029063 -0.020546 -0.002955  0.001830
# 3                 0 -0.002544  0.037302 -0.001819 -0.005451  0.005573
# 4                 0  0.027433  0.045905 -0.004089 -0.007748  0.006235
# ...             ...       ...       ...       ...       ...       ...
# 6224995           9 -1.107400  0.399240 -0.074573  0.192290  0.531560
# 6224996           9 -1.902100 -1.091000 -1.568400  0.225660  0.550410
# 6224997           9 -1.444000 -0.572160 -0.921060  0.289010  0.586970
# 6224998           9 -0.383910 -0.559630  0.385480  0.284010  0.591070
# 6224999           9 -0.757320 -0.555780  0.453100  0.153470  0.576230
#
#            gyro_z
# 0       -0.000880
# 1       -0.001606
# 2       -0.001985
# 3       -0.000610
# 4       -0.001509
# ...           ...
# 6224995  0.004095
# 6224996  0.006755
# 6224997  0.013448
# 6224998  0.027566
# 6224999  0.140510
#
# [6225000 rows x 7 columns]

# %% [markdown]
# # **Standardize the dataframe**
# Standardize the record count across all activities for each subject.

# %%
activity_counts = new_df.groupby('activityID').size()

# Print the counts for each activityID
print(activity_counts)
# Out:
# activityID
# 0     565800
# 1     562200
# 2     539100
# 3     559800
# 4     653400
# 5     543900
# 6     528600
# 7     399900
# 8     199800
# 9     144000
# 10    301500
# 11    264600
# 12     95100
# 13     77700
# 14    178500
# 15    239400
# 16    234300
# 17    137400
# dtype: int64

# %%
# # Count the number of records for each activityID
# activity_counts = new_df.groupby('activityID').size()

# # Find the minimum count of records
# min_records = activity_counts.min()

# # Print the minimum count and the corresponding activityID(s)
# min_activity_ids = activity_counts[activity_counts == min_records].index.tolist()

# print_log(f"Minimum number of records: {min_records}")
# print_log(f"Activity IDs with minimum records: {min_activity_ids}")

# %%
# # Count the number of records for each activityID
# activity_counts = new_df.groupby('activityID').size()

# # Find the minimum count of records
# min_records = activity_counts.min()

# # Initialize a list to store the resampled DataFrames
# equalized_dfs = []

# # Iterate through each activityID
# for activity_id in activity_counts.index:
#     # Filter the DataFrame for the current activityID
#     activity_data = new_df[new_df['activityID'] == activity_id]
    
#     # Resample the data to the minimum count with replacement
#     resampled_data = activity_data.sample(n=min_records, replace=True, random_state=42)
    
#     # Append the resampled DataFrame to the list
#     equalized_dfs.append(resampled_data)

# # Concatenate all resampled DataFrames into one
# equalized_df = pd.concat(equalized_dfs, ignore_index=True)
# print_log("The dataframe is Standardized")

# # Show the final equalized DataFrame
# print(equalized_df.groupby('activityID').size())  # Check the counts per activityID

# # Reassign the dataframe
# new_df = equalized_df
# new_df

# %%
new_df
# Out:
#          activityID     acc_x     acc_y     acc_z    gyro_x    gyro_y  \
# 0                 0  0.004231  0.005034 -0.020325 -0.000043  0.012474
# 1                 0 -0.000280  0.011153 -0.022526 -0.000816  0.010088
# 2                 0 -0.013906  0.029063 -0.020546 -0.002955  0.001830
# 3                 0 -0.002544  0.037302 -0.001819 -0.005451  0.005573
# 4                 0  0.027433  0.045905 -0.004089 -0.007748  0.006235
# ...             ...       ...       ...       ...       ...       ...
# 6224995           9 -1.107400  0.399240 -0.074573  0.192290  0.531560
# 6224996           9 -1.902100 -1.091000 -1.568400  0.225660  0.550410
# 6224997           9 -1.444000 -0.572160 -0.921060  0.289010  0.586970
# 6224998           9 -0.383910 -0.559630  0.385480  0.284010  0.591070
# 6224999           9 -0.757320 -0.555780  0.453100  0.153470  0.576230
#
#            gyro_z
# 0       -0.000880
# 1       -0.001606
# 2       -0.001985
# 3       -0.000610
# 4       -0.001509
# ...           ...
# 6224995  0.004095
# 6224996  0.006755
# 6224997  0.013448
# 6224998  0.027566
# 6224999  0.140510
#
# [6225000 rows x 7 columns]

# %% [markdown]
# # Visualize

# %%
def visualize_activity_data(activity_id, df):
    # Filter data for the specific activity ID
    activity_data = df[df['activityID'] == activity_id]
    
    # Ensure there are enough samples for plotting (300 samples)
    if len(activity_data) < 300:
        warn_log(f"Not enough samples for activity ID {activity_id}")
        return
    
    # Extract sensor data for the first 300 samples for each axis
    acc_x = activity_data['acc_x'].values[:300]
    acc_y = activity_data['acc_y'].values[:300]
    acc_z = activity_data['acc_z'].values[:300]
    gyro_x = activity_data['gyro_x'].values[:300]
    gyro_y = activity_data['gyro_y'].values[:300]
    gyro_z = activity_data['gyro_z'].values[:300]
    
    # Generate time array (assuming each sample is 0.01 seconds apart)
    time = np.linspace(0.01, 3, 300)
    
    # Create subplots
    plt.figure(figsize=(10, 18))
    
    # Plot accelerometer X axis
    ax1 = plt.subplot(611)
    ax1.plot(time, acc_x, color='b')
    ax1.title.set_text('Accelerometer X axis')
    ax1.set_xlabel('time (s)')
    ax1.set_ylabel('Acceleration (m/s^2)')
    ax1.grid(True)
    print_log("Accelerometer X axis plot is created")
    
    # Plot accelerometer Y axis
    ax2 = plt.subplot(612)
    ax2.plot(time, acc_y, color='g')
    ax2.title.set_text('Accelerometer Y axis')
    ax2.set_xlabel('time (s)')
    ax2.set_ylabel('Acceleration (m/s^2)')
    ax2.grid(True)
    print_log("Accelerometer Y axis plot is created")
    
    # Plot accelerometer Z axis
    ax3 = plt.subplot(613)
    ax3.plot(time, acc_z, color='r')
    ax3.title.set_text('Accelerometer Z axis')
    ax3.set_xlabel('time (s)')
    ax3.set_ylabel('Acceleration (m/s^2)')
    ax3.grid(True)
    print_log("Accelerometer Z axis plot is created")
    
    # Plot gyroscope X axis
    ax4 = plt.subplot(614)
    ax4.plot(time, gyro_x, color='b')
    ax4.title.set_text('Gyroscope X axis')
    ax4.set_xlabel('time (s)')
    ax4.set_ylabel('Angular rotation (rad/s)')
    ax4.grid(True)
    print_log("Gyroscope X axis plot is created")
    
    # Plot gyroscope Y axis
    ax5 = plt.subplot(615)
    ax5.plot(time, gyro_y, color='g')
    ax5.title.set_text('Gyroscope Y axis')
    ax5.set_xlabel('time (s)')
    ax5.set_ylabel('Angular rotation (rad/s)')
    ax5.grid(True)
    print_log("Gyroscope Y axis plot is created")
    
    # Plot gyroscope Z axis
    ax6 = plt.subplot(616)
    ax6.plot(time, gyro_z, color='r')
    ax6.title.set_text('Gyroscope Z axis')
    ax6.set_xlabel('time (s)')
    ax6.set_ylabel('Angular rotation (rad/s)')
    ax6.grid(True)
    print_log("Gyroscope Z axis plot is created")
    
    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
visualize_activity_data(activity_id=9, df=new_df)
# Out:
# INFO    | Line 31  | Accelerometer X axis plot is created
# INFO    | Line 40  | Accelerometer Y axis plot is created
# INFO    | Line 49  | Accelerometer Z axis plot is created
# INFO    | Line 58  | Gyroscope X axis plot is created
# INFO    | Line 67  | Gyroscope Y axis plot is created
# INFO    | Line 76  | Gyroscope Z axis plot is created

# %% [markdown]
# # Transform the data

# %%
# Function to create a DataFrame with original values, derivatives, and Fourier transforms
def create_transformed_df(df):
    transformed_data = {}

    # Include original values for each column, including activityID
    transformed_data['activityID'] = df['activityID']
    for col in ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z']:
        transformed_data[col] = df[col]  # Add original data

        # Compute first derivative
        transformed_data[f'{col}_fd'] = np.gradient(df[col])
        
        # Compute second derivative
        transformed_data[f'{col}_sd'] = np.gradient(transformed_data[f'{col}_fd'])
        
        # Compute Fourier Transform (absolute values to keep real magnitudes)
        transformed_data[f'{col}_fourier'] = np.abs(np.fft.fft(df[col]))

    # Create the final DataFrame
    transformed_df = pd.DataFrame(transformed_data)
    print_log("The first and secind derivatives, and Fourier transforms values of sensor data added in the dataframe")

    return transformed_df

# %%
def assign_subject_ids(df):
    # Get unique activity IDs in the dataset
    activity_ids = df['activityID'].unique()
    
    # Initialize list to hold subject IDs
    subject_ids = []
    
    # Loop over each activity ID
    for activity_id in activity_ids:
        # Get subset for the specific activity
        activity_df = df[df['activityID'] == activity_id]
        
        # Calculate the number of records per subject for the activity
        records_per_subject = len(activity_df) // 10
        
        # Create subject IDs (1 to 10) for each partition of the activity
        subject_id_repeated = np.repeat(np.arange(1, 11), records_per_subject)
        
        # Handle any leftover rows if records are not perfectly divisible by 10
        remaining = len(activity_df) - len(subject_id_repeated)
        subject_id_repeated = np.concatenate([subject_id_repeated, np.arange(1, remaining + 1)])
        
        # Append these subject IDs to the list
        subject_ids.extend(subject_id_repeated)
    
    # Add subjectID to the DataFrame
    df['subjectID'] = subject_ids
    print_log("subjectID is assign for every record")
    return df

# %%
# cretae transformed df it include first and second derivative and fourior, Assign the subject IDs from 0 to 10
transformed_df = create_transformed_df(new_df)
final_df = assign_subject_ids(transformed_df)
final_df
# Out:
# INFO    | Line 21  | The first and secind derivatives, and Fourier transforms values of sensor data added in the dataframe
# INFO    | Line 28  | subjectID is assign for every record
#          activityID     acc_x  acc_x_fd  acc_x_sd  acc_x_fourier     acc_y  \
# 0                 0  0.004231 -0.004511 -0.004557   3.409929e+08  0.005034
# 1                 0 -0.000280 -0.009068  0.001690   3.419450e+08  0.011153
# 2                 0 -0.013906 -0.001132  0.014869   3.443061e+08  0.029063
# 3                 0 -0.002544  0.020670  0.015777   3.480081e+08  0.037302
# 4                 0  0.027433  0.030422 -0.004276   3.536309e+08  0.045905
# ...             ...       ...       ...       ...            ...       ...
# 6224995           9 -1.107400 -0.330150 -0.144375   3.603005e+08  0.399240
# 6224996           9 -1.902100 -0.168300  0.544622   3.536309e+08 -1.091000
# 6224997           9 -1.444000  0.759095  0.255820   3.480081e+08 -0.572160
# 6224998           9 -0.383910  0.343340 -0.566252   3.443061e+08 -0.559630
# 6224999           9 -0.757320 -0.373410 -0.716750   3.419450e+08 -0.555780
#
#          acc_y_fd  acc_y_sd  acc_y_fourier     acc_z  ...  gyro_x_fourier  \
# 0        0.006119  0.005895   7.941640e+08 -0.020325  ...    3.067206e+06
# 1        0.012015  0.003478   7.940186e+08 -0.022526  ...    3.117677e+06
# 2        0.013074 -0.001797   7.932826e+08 -0.020546  ...    3.287769e+06
# 3        0.008421 -0.006358   7.919042e+08 -0.001819  ...    3.589566e+06
# 4        0.000359 -0.009117   7.899923e+08 -0.004089  ...    3.943388e+06
# ...           ...       ...            ...       ...  ...             ...
# 6224995 -1.069550 -0.241177   7.876171e+08 -0.074573  ...    4.461135e+06
# 6224996 -0.485700  0.667617   7.899923e+08 -1.568400  ...    3.943388e+06
# 6224997  0.265685  0.246945   7.919042e+08 -0.921060  ...    3.589566e+06
# 6224998  0.008190 -0.130918   7.932826e+08  0.385480  ...    3.287769e+06
# 6224999  0.003850 -0.004340   7.940186e+08  0.453100  ...    3.117677e+06
#
#            gyro_y  gyro_y_fd  gyro_y_sd  gyro_y_fourier    gyro_z  gyro_z_fd  \
# 0        0.012474  -0.002386  -0.002936    4.702947e+08 -0.000880  -0.000726
# 1        0.010088  -0.005322   0.000064    4.702819e+08 -0.001606  -0.000553
# 2        0.001830  -0.002258   0.003762    4.702521e+08 -0.001985   0.000498
# 3        0.005573   0.002203   0.001694    4.701781e+08 -0.000610   0.000238
# 4        0.006235   0.001131  -0.001527    4.700879e+08 -0.001509  -0.002137
# ...           ...        ...        ...             ...       ...        ...
# 6224995  0.531560   0.037025  -0.017020    4.699568e+08  0.004095  -0.056183
# 6224996  0.550410   0.027705  -0.008347    4.700879e+08  0.006755   0.004677
# 6224997  0.586970   0.020330  -0.016537    4.701781e+08  0.013448   0.010406
# 6224998  0.591070  -0.005370  -0.017585    4.702521e+08  0.027566   0.063531
# 6224999  0.576230  -0.014840  -0.009470    4.702819e+08  0.140510   0.112944
#
#          gyro_z_sd  gyro_z_fourier  subjectID
# 0         0.000174    8.738595e+08          1
# 1         0.000612    8.737983e+08          1
# 2         0.000395    8.735901e+08          1
# 3        -0.001317    8.733036e+08          1
# 4        -0.001183    8.728075e+08          1
# ...            ...             ...        ...
# 6224995   0.066720    8.722616e+08         10
# 6224996   0.033294    8.728075e+08         10
# 6224997   0.029427    8.733036e+08         10
# 6224998   0.051269    8.735901e+08         10
# 6224999   0.049413    8.737983e+08         10
#
# [6225000 rows x 26 columns]

# %%
def split_data(df, train_ratio=0.7, test_ratio=0.2, validation_ratio=0.1):
    # Initialize empty DataFrames for train, test, and validation
    train_df = pd.DataFrame(columns=df.columns)
    test_df = pd.DataFrame(columns=df.columns)
    validation_df = pd.DataFrame(columns=df.columns)

    # Iterate over each group of (activityID, subjectID)
    for (activity_id, subject_id), group in df.groupby(['activityID', 'subjectID']):
        n = len(group)
        train_end = int(train_ratio * n)
        test_end = train_end + int(test_ratio * n)
        
        # Split into train, test, validation based on indices
        train_data = group.iloc[:train_end]
        test_data = group.iloc[train_end:test_end]
        validation_data = group.iloc[test_end:]
        
        # Concatenate only if the DataFrames are not empty and have valid data
        if not train_data.empty and not train_data.isna().all().any():
            train_df = pd.concat([train_df, train_data], ignore_index=True)
        if not test_data.empty and not test_data.isna().all().any():
            test_df = pd.concat([test_df, test_data], ignore_index=True)
        if not validation_data.empty and not validation_data.isna().all().any():
            validation_df = pd.concat([validation_df, validation_data], ignore_index=True)
    
    print_log("Data is splited in 3 part such as tran, test and validation")

    return train_df, test_df, validation_df

# %%
train_df, test_df, validation_df = split_data(final_df)

print_log(f"Train data shape : {train_df.shape}")
print_log(f"Test data shape: {test_df.shape}")
print_log(f"Validation data shape: {validation_df.shape}")

# # Define the file paths for saving the CSV files
# train_csv_path = '/kaggle/working/train_data.csv'
# test_csv_path = '/kaggle/working/test_data.csv'
# validation_csv_path = '/kaggle/working/validation_data.csv'

# # Save the DataFrames to CSV files
# train_df.to_csv(train_csv_path, index=False)
# print_log("train_data.csv file is created")
# test_df.to_csv(test_csv_path, index=False)
# print_log("test_data.csv file is created")
# validation_df.to_csv(validation_csv_path, index=False)
# print_log("validation_data.csv file is created")
# Out:
# /tmp/ipykernel_24/1035667665.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_df = pd.concat([train_df, train_data], ignore_index=True)
# /tmp/ipykernel_24/1035667665.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   test_df = pd.concat([test_df, test_data], ignore_index=True)
# /tmp/ipykernel_24/1035667665.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   validation_df = pd.concat([validation_df, validation_data], ignore_index=True)
# INFO    | Line 26  | Data is splited in 3 part such as tran, test and validation
# INFO    | Line 3   | Train data shape : (4357496, 26)
# INFO    | Line 4   | Test data shape: (1245000, 26)
# INFO    | Line 5   | Validation data shape: (622504, 26)

# %%
train_df.groupby(['activityID', 'subjectID']).size()
# Out:
# activityID  subjectID
# 0           1            39606
#             2            39606
#             3            39606
#             4            39606
#             5            39606
#                          ...
# 17          4             4326
#             7             4094
#             8            12495
#             9            12495
#             10           12495
# Length: 156, dtype: int64

# %%
def generate_sequence_list(df, sequence_length=500, overlap=20):
    # Initialize the main list to hold all sequences for all activities
    imu_data_sequence = []

    # Group by activityID to handle each activity separately
    grouped_by_activity = df.groupby('activityID')

    # Iterate over each activity group
    for activity_id, activity_group in grouped_by_activity:
        # Initialize a list for this activity
        activity_data_sequence = []

        # Group by subjectID within the activity group
        grouped_by_subject = activity_group.groupby('subjectID')
        
        # Iterate over each subject group within the activity
        for subject_id, subject_group in grouped_by_subject:
            # Extract the data values excluding activityID and subjectID
            data_values = subject_group.drop(columns=['activityID', 'subjectID']).values
            
            # Calculate the number of sequences
            num_samples = len(data_values)
            num_sequences = (num_samples - sequence_length) // overlap + 1
            
            # Create a list for this subject's sequences
            subject_sequences = []
            
            # Generate sequences for this subject
            for i in range(num_sequences):
                sequence_start = i * overlap
                sequence_end = sequence_start + sequence_length
                if sequence_end <= num_samples:
                    # Append the sequence to the subject's sequence list
                    subject_sequences.append(data_values[sequence_start:sequence_end])
            
            # Add the subject sequences to the activity's list
            activity_data_sequence.append(subject_sequences)
            debug_log(f"The sequences are generated for subjectID: {subject_id}")
        
        # After processing all subjects, print activity completion
        print_log(f"The sequences are generated for activityID: {activity_id}")

        # Add the activity data sequence to the main list
        imu_data_sequence.append(activity_data_sequence)

    return imu_data_sequence

# %%
# Generate sequences for each DataFrame
imu_data_sequence_train = generate_sequence_list(train_df)
imu_data_sequence_test = generate_sequence_list(test_df)
imu_data_sequence_validation = generate_sequence_list(validation_df)
# Out:
# INFO    | Line 41  | The sequences are generated for activityID: 0
# INFO    | Line 41  | The sequences are generated for activityID: 1
# INFO    | Line 41  | The sequences are generated for activityID: 2
# INFO    | Line 41  | The sequences are generated for activityID: 3
# INFO    | Line 41  | The sequences are generated for activityID: 4
# INFO    | Line 41  | The sequences are generated for activityID: 5
# INFO    | Line 41  | The sequences are generated for activityID: 6
# INFO    | Line 41  | The sequences are generated for activityID: 7
# INFO    | Line 41  | The sequences are generated for activityID: 8
# INFO    | Line 41  | The sequences are generated for activityID: 9
# INFO    | Line 41  | The sequences are generated for activityID: 10
# INFO    | Line 41  | The sequences are generated for activityID: 11
# INFO    | Line 41  | The sequences are generated for activityID: 12
# INFO    | Line 41  | The sequences are generated for activityID: 13
# INFO    | Line 41  | The sequences are generated for activityID: 14
# INFO    | Line 41  | The sequences are generated for activityID: 15
# INFO    | Line 41  | The sequences are generated for activityID: 16
# INFO    | Line 41  | The sequences are generated for activityID: 17
# INFO    | Line 41  | The sequences are generated for activityID: 0
# INFO    | Line 41  | The sequences are generated for activityID: 1
# INFO    | Line 41  | The sequences are generated for activityID: 2
# INFO    | Line 41  | The sequences are generated for activityID: 3
# INFO    | Line 41  | The sequences are generated for activityID: 4
# INFO    | Line 41  | The sequences are generated for activityID: 5
# INFO    | Line 41  | The sequences are generated for activityID: 6
# INFO    | Line 41  | The sequences are generated for activityID: 7
# INFO    | Line 41  | The sequences are generated for activityID: 8
# INFO    | Line 41  | The sequences are generated for activityID: 9
# INFO    | Line 41  | The sequences are generated for activityID: 10
# INFO    | Line 41  | The sequences are generated for activityID: 11
# INFO    | Line 41  | The sequences are generated for activityID: 12
# INFO    | Line 41  | The sequences are generated for activityID: 13
# INFO    | Line 41  | The sequences are generated for activityID: 14
# INFO    | Line 41  | The sequences are generated for activityID: 15
# INFO    | Line 41  | The sequences are generated for activityID: 16
# INFO    | Line 41  | The sequences are generated for activityID: 17
# INFO    | Line 41  | The sequences are generated for activityID: 0
# INFO    | Line 41  | The sequences are generated for activityID: 1
# INFO    | Line 41  | The sequences are generated for activityID: 2
# INFO    | Line 41  | The sequences are generated for activityID: 3
# INFO    | Line 41  | The sequences are generated for activityID: 4
# INFO    | Line 41  | The sequences are generated for activityID: 5
# INFO    | Line 41  | The sequences are generated for activityID: 6
# INFO    | Line 41  | The sequences are generated for activityID: 7
# INFO    | Line 41  | The sequences are generated for activityID: 8
# INFO    | Line 41  | The sequences are generated for activityID: 9
# INFO    | Line 41  | The sequences are generated for activityID: 10
# INFO    | Line 41  | The sequences are generated for activityID: 11
# INFO    | Line 41  | The sequences are generated for activityID: 12
# INFO    | Line 41  | The sequences are generated for activityID: 13
# INFO    | Line 41  | The sequences are generated for activityID: 14
# INFO    | Line 41  | The sequences are generated for activityID: 15
# INFO    | Line 41  | The sequences are generated for activityID: 16
# INFO    | Line 41  | The sequences are generated for activityID: 17

# %%
len(imu_data_sequence_train[1][3])
# Out:
# 1733

# %% [markdown]
# # Store data as a pickle

# %%
# # Store the imu data as a pickle
# pickle_imu_data_directory = "/kaggle/working/pickle_imu_data"

# # Create the directory if it doesn't exist
# os.makedirs(pickle_imu_data_directory, exist_ok=True)

# # File paths for pickle files
# train_pickle_path = os.path.join(pickle_imu_data_directory, 'imu_data_sequence_train.pkl')
# test_pickle_path = os.path.join(pickle_imu_data_directory, 'imu_data_sequence_test.pkl')
# validation_pickle_path = os.path.join(pickle_imu_data_directory, 'imu_data_sequence_validation.pkl')

# # Save the training data sequence to a pickle file
# with open(train_pickle_path, 'wb') as train_file:
#     pickle.dump(imu_data_sequence_train[0:8], train_file)
# print_log("Train Pickle file has been saved successfully")

# # Save the testing data sequence to a pickle file
# with open(test_pickle_path, 'wb') as test_file:
#     pickle.dump(imu_data_sequence_test[0:8], test_file)
# print_log("Test Pickle file has been saved successfully")

# # Save the validation data sequence to a pickle file
# with open(validation_pickle_path, 'wb') as validation_file:
#     pickle.dump(imu_data_sequence_validation[0:8], validation_file)
# print_log("Validation Pickle file has been saved successfully")

# print("Pickle files have been saved successfully.")

# %% [markdown]
# # Model

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, k, d_model, seq_len):
        super().__init__()
        
        self.embedding = nn.Parameter(torch.zeros([k, d_model], dtype=torch.float), requires_grad=True)
        nn.init.xavier_uniform_(self.embedding, gain=1)
        self.positions = torch.tensor([i for i in range(seq_len)], requires_grad=False).unsqueeze(1).repeat(1, k)
        s = 0.0
        interval = seq_len / k
        mu = []
        for _ in range(k):
            mu.append(nn.Parameter(torch.tensor(s, dtype=torch.float), requires_grad=True))
            s = s + interval
        self.mu = nn.Parameter(torch.tensor(mu, dtype=torch.float).unsqueeze(0), requires_grad=True)
        self.sigma = nn.Parameter(torch.tensor([torch.tensor([50.0], dtype=torch.float, requires_grad=True) for _ in range(k)]).unsqueeze(0))
        
    def normal_pdf(self, pos, mu, sigma):
        a = pos - mu
        log_p = -1*torch.mul(a, a)/(2*(sigma**2)) - torch.log(sigma)
        return torch.nn.functional.softmax(log_p, dim=1)

    def forward(self, inputs):
        pdfs = self.normal_pdf(self.positions, self.mu, self.sigma)
        pos_enc = torch.matmul(pdfs, self.embedding)
        
        return inputs + pos_enc.unsqueeze(0).repeat(inputs.size(0), 1, 1)

class TransformerEncoderLayer(nn.Module):
    def __init__(self, d_model, heads, _heads, dropout, seq_len):
        super(TransformerEncoderLayer, self).__init__()
        
        self.attention = nn.MultiheadAttention(d_model, heads, batch_first=True)
        self._attention = nn.MultiheadAttention(seq_len, _heads, batch_first=True)
        
        self.attn_norm = nn.LayerNorm(d_model)
        
        self.cnn_units = 1
        
        self.cnn = nn.Sequential(
            nn.Conv2d(1, self.cnn_units, (1, 1)),
            nn.BatchNorm2d(self.cnn_units),
            nn.Dropout(dropout),
            nn.ReLU(),
            nn.Conv2d(self.cnn_units, self.cnn_units, (3, 3), padding=1),
            nn.BatchNorm2d(self.cnn_units),
            nn.Dropout(dropout),
            nn.ReLU(),
            nn.Conv2d(self.cnn_units, 1, (5, 5), padding=2),
            nn.BatchNorm2d(1),
            nn.Dropout(dropout),
            nn.ReLU()
        )
        
        self.final_norm = nn.LayerNorm(d_model)

    def forward(self, src, src_mask=None):
        src = self.attn_norm(src + self.attention(src, src, src)[0] + self._attention(src.transpose(-1, -2), src.transpose(-1, -2), src.transpose(-1, -2))[0].transpose(-1, -2))
        
        src = self.final_norm(src + self.cnn(src.unsqueeze(dim=1)).squeeze(dim=1))
            
        return src

class TransformerEncoder(nn.Module):
    def __init__(self, d_model, heads, _heads, seq_len, num_layer=2, dropout=0.1):
        super(TransformerEncoder, self).__init__()

        self.layers = nn.ModuleList()
        for i in range(num_layer):
            self.layers.append(TransformerEncoderLayer(d_model, heads, _heads, dropout, seq_len))

    def forward(self, src):
        for layer in self.layers:
            src = layer(src)

        return src

class Transformer(nn.Module):
    def __init__(self, num_layer, d_model, k, heads, _heads, seq_len, trg_len, dropout):
        super(Transformer, self).__init__()

        self.pos_encoding = PositionalEncoding(k, d_model, seq_len)

        self.encoder = TransformerEncoder(d_model, heads, _heads, seq_len, num_layer, dropout)

    def forward(self, inputs):
        encoded_inputs = self.pos_encoding(inputs)

        return self.encoder(encoded_inputs)

class Model(nn.Module):
    def __init__(self, feature_count, l, trg_len, num_classes):
        super(Model, self).__init__()
        
        self.imu_transformer = Transformer(5, feature_count, 100, 4, 4, l, trg_len, 0.1)
        
        self.linear_imu = nn.Sequential(
            nn.Linear(feature_count*l, (feature_count*l)//2),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear((feature_count*l)//2, trg_len),
            nn.ReLU()
        )
        
        # Batch normalization and dropout layers
        self.batch_norm = nn.BatchNorm1d(trg_len)
        self.dropout = nn.Dropout(0.5)
        
        # Classifier layer
        self.classifier = nn.Linear(trg_len, num_classes)

    def forward(self, inputs):
        
        embedding = self.linear_imu(torch.flatten(self.imu_transformer(inputs), start_dim=1, end_dim=2))
        
        # Apply batch normalization
        embedding = self.batch_norm(embedding)
        
        # Apply dropout
        embedding = self.dropout(embedding)
        
        # Get class scores
        class_scores = self.classifier(embedding)
        
        return class_scores, embedding

# %% [markdown]
# # If you have GPU

# %%
torch.set_default_tensor_type('torch.cuda.FloatTensor')
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /usr/local/src/pytorch/torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)

# %%
batch_size=BATCH_SIZE
epoch_batch_count=EPOCH_BATCH_COUNT
imu_l=500#sequence length
imu_feature_count=IMU_FEATURE_COUNT
trg_len=128 # this will be the size of feature embedding
classes=CLASSES

# %%
best_model_save_path = '/kaggle/working/best_models'
checkpoint_save_path = '/kaggle/working/checkpoints'

subprocess.run(f"mkdir {best_model_save_path}", shell=True)
subprocess.run(f"mkdir {checkpoint_save_path}", shell=True)
# Out:
# CompletedProcess(args='mkdir /kaggle/working/checkpoints', returncode=0)

# %%
class TrainDataset(Dataset):
    def __init__(self, training_data, batch_size, epoch_batch_count):
        self.training_data = training_data
        self.batch_size = batch_size
        self.epoch_batch_count = epoch_batch_count

    def __len__(self):
        return self.batch_size * self.epoch_batch_count

    def __getitem__(self, idx):
        while True:
            try:
                genuine_user_idx = np.random.randint(0, len(self.training_data))
                imposter_user_idx = np.random.randint(0, len(self.training_data))
                
                # Ensure imposter_user_idx is different from genuine_user_idx
                while imposter_user_idx == genuine_user_idx:
                    imposter_user_idx = np.random.randint(0, len(self.training_data))
                
                # Validate the lengths of genuine_user and imposter_user data
                if len(self.training_data[genuine_user_idx]) == 0 or len(self.training_data[imposter_user_idx]) == 0:
                    raise ValueError("Empty user data detected.")
                
                genuine_sess_1 = np.random.randint(0, len(self.training_data[genuine_user_idx]))
                genuine_sess_2 = np.random.randint(0, len(self.training_data[genuine_user_idx]))
                
                # Ensure genuine_sess_2 is different from genuine_sess_1
                while genuine_sess_2 == genuine_sess_1:
                    genuine_sess_2 = np.random.randint(0, len(self.training_data[genuine_user_idx]))
                
                # Validate the lengths of genuine_sess_1 and genuine_sess_2 data
                if len(self.training_data[genuine_user_idx][genuine_sess_1]) == 0 or len(self.training_data[genuine_user_idx][genuine_sess_2]) == 0:
                    raise ValueError("Empty session data detected.")
                
                imposter_sess = np.random.randint(0, len(self.training_data[imposter_user_idx]))
                
                # Validate the length of imposter_sess data
                if len(self.training_data[imposter_user_idx][imposter_sess]) == 0:
                    raise ValueError("Empty imposter session data detected.")
                
                genuine_seq_1 = np.random.randint(0, len(self.training_data[genuine_user_idx][genuine_sess_1]))
                genuine_seq_2 = np.random.randint(0, len(self.training_data[genuine_user_idx][genuine_sess_2]))
                imposter_seq = np.random.randint(0, len(self.training_data[imposter_user_idx][imposter_sess]))
#                 debug_log(f"{genuine_user_idx}, {genuine_sess_1}, {genuine_sess_2}, {imposter_user_idx}, {imposter_sess}")
                anchor = self.training_data[genuine_user_idx][genuine_sess_1][genuine_seq_1]
                positive = self.training_data[genuine_user_idx][genuine_sess_2][genuine_seq_2]
                negative = self.training_data[imposter_user_idx][imposter_sess][imposter_seq]

                return anchor, positive, negative, genuine_user_idx, imposter_user_idx
            
            except ValueError as e:
                error_log(f"Encountered ValueError: {str(e)}. Retrying with new indices.")

# %%
class TripletLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(TripletLoss, self).__init__()
        self.margin = margin
        
    def calc_euclidean(self, x1, x2):
        return (x1 - x2).pow(2).sum(dim=1).sqrt()
    
    def calc_cosine(self, x1, x2):
        dot_product_sum = (x1*x2).sum(dim=1)
        norm_multiply = (x1.pow(2).sum(dim=1).sqrt()) * (x2.pow(2).sum(dim=1).sqrt())
        return dot_product_sum / norm_multiply
    
    def calc_manhattan(self, x1, x2):
        return (x1-x2).abs().sum(dim=1)
    
    def forward(self, anchor, positive, negative):
        distance_positive = self.calc_euclidean(anchor, positive)
        distance_negative = self.calc_euclidean(anchor, negative)
        losses = torch.relu(distance_positive - distance_negative + self.margin)

        return losses.mean()

# %% [markdown]
# # Set the classes

# %%
train_data = imu_data_sequence_train[0:CLASSES]
test_data = imu_data_sequence_test[0:CLASSES]
validation_data = imu_data_sequence_validation[0:CLASSES]

# %%
dataset = TrainDataset(train_data, batch_size, epoch_batch_count)
dataloader = DataLoader(dataset, batch_size=batch_size)
model = Model(imu_feature_count, imu_l, trg_len,classes)

# %%
loss_fn = TripletLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE,weight_decay=1e-5) # change the learning rate
# optimizer = optim.Adam(model.parameters(), lr=0.0005)

# %%
g_eer = math.inf
init_epoch = 0
epochs=EPOCHS #increase the epochs

# %%
plt.style.use('seaborn-v0_8-bright')
plt.rcParams['axes.facecolor'] = 'white'
mpl.rcParams.update({"axes.grid" : True, "grid.color": "black"})
mpl.rc('axes',edgecolor='black')
mpl.rcParams.update({'font.size': 13})

# %%
# class TestDataset(Dataset):
#     def __init__(self, eval_data):
#         self.eval_data = eval_data
#         self.num_sessions = len(self.eval_data[0])
#         self.num_seqs = len(self.eval_data[0][0])

#     def __len__(self):
#         return math.ceil(len(self.eval_data) * self.num_sessions * self.num_seqs)

#     def __getitem__(self, idx):
#         t_session = idx // self.num_seqs
#         user_idx = t_session // self.num_sessions
#         session_idx = t_session % self.num_sessions
#         seq_idx = idx % self.num_seqs
        
#         # Debugging statements
#         debug_log(f"Index: {idx}, User Index: {user_idx}, Session Index: {session_idx}, Sequence Index: {seq_idx}")
        
#         # Ensure that indices are within valid range
#         if user_idx < len(self.eval_data) and session_idx < len(self.eval_data[user_idx]) and seq_idx < len(self.eval_data[user_idx][session_idx]):
            
#             debug_log(f"The length {len(self.eval_data[user_idx][session_idx][seq_idx])} ")
#             debug_log(f"test ,{user_idx}, {session_idx},{ seq_idx}")
#             data = self.eval_data[user_idx][session_idx][seq_idx]

#             # Debugging statement to check the returned data
#             if data is None:
#                 error_log(f"Returned data is None for index: {idx} in testdata")

#             return data,user_idx
#         else:
#             pass

# %%
# The lenth of sequence calculate dynamically
class TestDataset(Dataset):
    def __init__(self, eval_data):
        self.eval_data = eval_data
        self.num_sessions = [len(user_sessions) for user_sessions in self.eval_data]  # List of number of sessions for each user
        self.num_seqs = [len(session) for user_sessions in self.eval_data for session in user_sessions]  # Total sequences across all users

    def __len__(self):
        # Total length of dataset will be the sum of all sequences across all users and sessions
        return sum(len(self.eval_data[user_idx][session_idx]) for user_idx in range(len(self.eval_data))
                   for session_idx in range(len(self.eval_data[user_idx])))

    def __getitem__(self, idx):
        # Find the user index and session index dynamically
        cumulative_length = 0
        for user_idx in range(len(self.eval_data)):
            for session_idx in range(len(self.eval_data[user_idx])):
                session_length = len(self.eval_data[user_idx][session_idx])
                if cumulative_length + session_length > idx:
                    seq_idx = idx - cumulative_length
                    data = self.eval_data[user_idx][session_idx][seq_idx]

                    # Debugging statements
                    debug_log(f"Index: {idx}, User Index: {user_idx}, Session Index: {session_idx}, Sequence Index: {seq_idx}")

                    # Check if data is None
                    if data is None:
                        error_log(f"Returned data is None for index: {idx} in testdata")
                    return data, user_idx

                cumulative_length += session_length
        
        # If we get here, idx is out of bounds
        raise IndexError("Index out of bounds for dataset.")

# %%
best_accuracy = BEST_ACCURACY
best_loss = BEST_LOSS
training_losses = []
validation_losses = []
feature_embeddings_train=[]
saved_models = []
max_saved_models = MAX_SAVED_MODELS

# %% [markdown]
# # Training phase and store the model based on loss
#
# The number of model store based on variable MAX_SAVED_MODELS

# %%
# # epochs=1
# for i in range(init_epoch, epochs):
#     print_log(f"Epoch - {i+1} is started")
# #     print(torch.cuda.memory_summary())
# #     pred_train = torch.tensor([], dtype=torch.long)
# #     label_train = torch.tensor([], dtype=torch.long)
# #     all_labels = torch.tensor([], dtype=torch.long)
# #     all_preds = torch.tensor([], dtype=torch.long)
#     t_loss = 0.0
#     start = time.time()
#     model.train(True)
    
#     # Training phase
#     for batch_idx, item in enumerate(dataloader):
#         anchor, positive, negative, anchor_class,negative_class = item
#         optimizer.zero_grad()
# #         print(len(anchor))
#         # Forward pass for triplet loss
#         anchor_class_scores,anchor_features= model(anchor.float())
#         positive_class_scores,positive_features = model(positive.float())
#         negative_class_scores,negative_features = model(negative.float())
# #         print(len(anchor_features),"anchor_features")
# #         feature_embeddings_train.append(anchor_features)
# #         feature_embeddings_train.append(positive_features)
# #         feature_embeddings_train.append(negative_features)
# #         post_enc_test.append(post_enc_anchor)
# #         post_enc_test.append(post_enc_positive)
# #         post_enc_test.append(post_enc_negative)
        
# #         print(len(feature_embeddings_train),"feature_embeddings_train")
#         # Compute triplet loss
#         triplet_loss = loss_fn(anchor_features, positive_features, negative_features)
# #         triplet_loss=0
#         # Forward pass for classification loss
# #         print(anchor_class,"anchor_class_scores")
# #         all_class_scores = torch.cat([anchor_class_scores, positive_class_scores, negative_class_scores], dim=0)
# #         all_labels_train = torch.cat([anchor_class, anchor_class, negative_class], dim=0)  # Assuming the third element is the label
# #         predicted_classes_train = torch.argmax(all_class_scores, dim=1)
# #         print(len(all_class_scores),"all_class_scores")
# #         pred_train.extend(predicted_classes_train)
# #         label_train.extend(all_labels_train)
# #         pred_train = torch.cat((pred_train, predicted_classes_train), dim=0)
# #         label_train = torch.cat((label_train, all_labels_train), dim=0)
# #         correct_predictions_train= (predicted_classes_train == all_labels)

# #         accuracy_train = correct_predictions_train.sum().item() / len(all_labels)
# #         print("accuracy of train", accuracy_train)
#         # Compute classification loss
#         #class_loss = classification_loss_fn(all_class_scores, all_labels_train)
        
#         # Combine losses
#         total_loss = triplet_loss #+ class_loss
# #         total_loss=class_loss
# #         print(class_loss,"class_loss",triplet_loss,"triplet_loss")
#         total_loss.backward()
#         optimizer.step()
        
#         t_loss += total_loss.item()
    
#     t_loss /= len(dataloader)
#     training_losses.append(t_loss)
    
# #     accuracy_train = accuracy_score(all_labels_train, predicted_classes_train)
# #     print("accuracy of train", accuracy_train)
#     # Validation phase
#     model.eval()
#     v_loss = 0.0
#     all_preds = []
#     all_labels = []
#     t_dataset = TestDataset(validation_data)
    
#     t_dataloader = DataLoader(t_dataset, batch_size=batch_size, shuffle=False)
#     tot = 0
#     print_log(f"The lenth of t_dataloader : {len(t_dataloader)}")
#     for batch_idx_t, item_t in enumerate(t_dataloader):
#         with torch.no_grad():
#             val = tot // 992
#             tot += 1
            
#             item_t_in,class_label=item_t
#             item_out = model(item_t_in.float())
#             class_scores = item_out[0]
# #             post_enc_val=item_out[2]
# #             post_enc_test.append(post_enc_val)
#             true_labels = class_label
#             predicted_classes = torch.argmax(class_scores, dim=1)
            
#             correct_predictions = (predicted_classes == true_labels)
            
#             accuracy = correct_predictions.sum().item() / len(true_labels)
            
# #             print(f"Batch {batch_idx_t} - True Labels: {true_labels.tolist()} - Predicted: {predicted_classes.tolist()} -Class Labels: {class_label}")
#             all_preds.extend(predicted_classes.tolist())
#             all_labels.extend(true_labels.tolist())
# #             val_loss = classification_loss_fn(class_scores, true_labels)
# #             v_loss += val_loss.item()
# #     v_loss /= len(t_dataloader)
# #     validation_losses.append(v_loss)
#     accuracy = accuracy_score(all_labels, all_preds)
#     precision = precision_score(all_labels, all_preds, average='macro')
#     recall = recall_score(all_labels, all_preds, average='macro')
#     f1 = f1_score(all_labels, all_preds, average='macro')
#     print_log(f"loop done  {tot}")
#     end = time.time()
    
#     print_log(f"------> Epoch No: {i+1} - Loss: {t_loss:.6f} - Accuracy: {accuracy:.6f} - Precision: {precision:.6f} - Recall: {recall:.6f} - F1: {f1:.6f} - Time: {end-start:.2f}")
# #     scheduler.step(t_loss)
    
#     # Save model if validation loss is better
#     if t_loss < best_loss:
#         print_log(f"Loss improved from {best_loss:.6f} to {t_loss:.6f}. Saving model...")
#         best_loss = t_loss
#         torch.save(model, best_model_save_path + f"/epoch_{i+1}accuracy{accuracy}.pt")
#         model_path=best_model_save_path + f"/epoch_{i+1}accuracy{accuracy}.pt"
#         print_log(f"Best model is saved in model_path (by losses): {model_path}")
#         saved_models.append(model_path)
#         if len(saved_models) > max_saved_models:
#             # Remove the oldest saved model
#             oldest_model = saved_models.pop(0)
#             if os.path.exists(oldest_model):
#                 os.remove(oldest_model)
#                 print_log(f"Deleted old model: {oldest_model}")
            
#     # Save checkpoint every 50 epochs
# #     if (i+1) % 50 == 0:
# #         torch.save({
# #             'epoch': i+1,
# #             'model_state_dict': model.state_dict(),
# #             'optimizer_state_dict': optimizer.state_dict(),
# #             'accuracy': accuracy
# #         }, f"{checkpoint_save_path}/checkpoint_epoch_{i+1}.tar")

# %% [markdown]
# # Training phase and store the model based on accuracy
#
# The number of model store based on variable MAX_SAVED_MODEL

# %%
# # epochs=1
# for i in range(init_epoch, epochs):
#     print_log(f"Epoch - {i+1} is started")
# #     print(torch.cuda.memory_summary())
# #     pred_train = torch.tensor([], dtype=torch.long)
# #     label_train = torch.tensor([], dtype=torch.long)
# #     all_labels = torch.tensor([], dtype=torch.long)
# #     all_preds = torch.tensor([], dtype=torch.long)
#     t_loss = 0.0
#     start = time.time()
#     model.train(True)
    
#     # Training phase
#     for batch_idx, item in enumerate(dataloader):
#         anchor, positive, negative, anchor_class,negative_class = item
#         optimizer.zero_grad()
# #         print(len(anchor))
#         # Forward pass for triplet loss
#         anchor_class_scores,anchor_features= model(anchor.float())
#         positive_class_scores,positive_features = model(positive.float())
#         negative_class_scores,negative_features = model(negative.float())
# #         print(len(anchor_features),"anchor_features")
# #         feature_embeddings_train.append(anchor_features)
# #         feature_embeddings_train.append(positive_features)
# #         feature_embeddings_train.append(negative_features)
# #         post_enc_test.append(post_enc_anchor)
# #         post_enc_test.append(post_enc_positive)
# #         post_enc_test.append(post_enc_negative)
        
# #         print(len(feature_embeddings_train),"feature_embeddings_train")
#         # Compute triplet loss
#         triplet_loss = loss_fn(anchor_features, positive_features, negative_features)
# #         triplet_loss=0
#         # Forward pass for classification loss
# #         print(anchor_class,"anchor_class_scores")
# #         all_class_scores = torch.cat([anchor_class_scores, positive_class_scores, negative_class_scores], dim=0)
# #         all_labels_train = torch.cat([anchor_class, anchor_class, negative_class], dim=0)  # Assuming the third element is the label
# #         predicted_classes_train = torch.argmax(all_class_scores, dim=1)
# #         print(len(all_class_scores),"all_class_scores")
# #         pred_train.extend(predicted_classes_train)
# #         label_train.extend(all_labels_train)
# #         pred_train = torch.cat((pred_train, predicted_classes_train), dim=0)
# #         label_train = torch.cat((label_train, all_labels_train), dim=0)
# #         correct_predictions_train= (predicted_classes_train == all_labels)

# #         accuracy_train = correct_predictions_train.sum().item() / len(all_labels)
# #         print("accuracy of train", accuracy_train)
#         # Compute classification loss
#         #class_loss = classification_loss_fn(all_class_scores, all_labels_train)
        
#         # Combine losses
#         total_loss = triplet_loss #+ class_loss
# #         total_loss=class_loss
# #         print(class_loss,"class_loss",triplet_loss,"triplet_loss")
#         total_loss.backward()
#         optimizer.step()
        
#         t_loss += total_loss.item()
    
#     t_loss /= len(dataloader)
#     training_losses.append(t_loss)

    
    
# #     accuracy_train = accuracy_score(all_labels_train, predicted_classes_train)
# #     print("accuracy of train", accuracy_train)
#     # Validation phase
#     model.eval()
#     v_loss = 0.0
#     all_preds = []
#     all_labels = []
#     t_dataset = TestDataset(validation_data)
    
#     t_dataloader = DataLoader(t_dataset, batch_size=batch_size, shuffle=False)
#     tot = 0
#     print_log(f"The lenth of t_dataloader : {len(t_dataloader)}")
#     for batch_idx_t, item_t in enumerate(t_dataloader):
#         with torch.no_grad():
#             val = tot // 992
#             tot += 1
            
#             item_t_in,class_label=item_t
#             item_out = model(item_t_in.float())
#             class_scores = item_out[0]
# #             post_enc_val=item_out[2]
# #             post_enc_test.append(post_enc_val)
#             true_labels = class_label
#             predicted_classes = torch.argmax(class_scores, dim=1)
            
#             correct_predictions = (predicted_classes == true_labels)
            
#             accuracy = correct_predictions.sum().item() / len(true_labels)
            
# #             print(f"Batch {batch_idx_t} - True Labels: {true_labels.tolist()} - Predicted: {predicted_classes.tolist()} -Class Labels: {class_label}")
#             all_preds.extend(predicted_classes.tolist())
#             all_labels.extend(true_labels.tolist())
# #             val_loss = classification_loss_fn(class_scores, true_labels)
# #             v_loss += val_loss.item()
# #     v_loss /= len(t_dataloader)
# #     validation_losses.append(v_loss)
#     accuracy = accuracy_score(all_labels, all_preds)
#     precision = precision_score(all_labels, all_preds, average='macro')
#     recall = recall_score(all_labels, all_preds, average='macro')
#     f1 = f1_score(all_labels, all_preds, average='macro')
#     print_log(f"loop done  {tot}")
#     end = time.time()
    
#     print_log(f"------> Epoch No: {i+1} - Loss: {t_loss:.6f} - Accuracy: {accuracy:.6f} - Precision: {precision:.6f} - Recall: {recall:.6f} - F1: {f1:.6f} - Time: {end-start:.2f}")
# #     scheduler.step(t_loss)
    

#     # Save model if validation accuracy is improved
#     if accuracy > best_accuracy:
#         print_log(f"Accuracy improved from {best_accuracy:.6f} to {accuracy:.6f}. Saving model...")
#         best_accuracy = accuracy
#         torch.save(model, best_model_save_path + f"/epoch_{i+1}_accuracy_{accuracy:.6f}.pt")
#         model_path_accuracy = best_model_save_path + f"/epoch_{i+1}_accuracy_{accuracy:.6f}.pt"
#         print_log(f"Best model is saved in model_path (by accuracy): {model_path_accuracy}")
#         saved_models.append(model_path_accuracy)
#         if len(saved_models) > max_saved_models:
#             oldest_model_accuracy = saved_models.pop(0)
#             if os.path.exists(oldest_model_accuracy):
#                 os.remove(oldest_model_accuracy)
#                 print_log(f"Deleted old model (by accuracy): {oldest_model_accuracy}")

# %% [markdown]
# # Training phase and store the model based on losses, Calculate Training and validation accuracy
#
# The number of model store based on variable MAX_SAVED_MODEL

# %%
# Initialize accuracy lists
training_accuracies = []
validation_accuracies = []

# Training loop
# epochs=1
for i in range(init_epoch, epochs):
    print_log(f"Epoch - {i+1} is started")
    #     print(torch.cuda.memory_summary())
    #     pred_train = torch.tensor([], dtype=torch.long)
    #     label_train = torch.tensor([], dtype=torch.long)
    #     all_labels = torch.tensor([], dtype=torch.long)
    #     all_preds = torch.tensor([], dtype=torch.long)
    
    t_loss = 0.0
    correct_train_preds = 0
    total_train_samples = 0
    start = time.time()
    model.train(True)

    # Training phase
    for batch_idx, item in enumerate(dataloader):
        anchor, positive, negative, anchor_class, negative_class = item
        optimizer.zero_grad()
        
        # print(len(anchor))
        # Forward pass for triplet loss
        anchor_class_scores,anchor_features= model(anchor.float())
        positive_class_scores,positive_features = model(positive.float())
        negative_class_scores,negative_features = model(negative.float())
        # print(len(anchor_features),"anchor_features")
        # feature_embeddings_train.append(anchor_features)
        # feature_embeddings_train.append(positive_features)
        # feature_embeddings_train.append(negative_features)
        # post_enc_test.append(post_enc_anchor)
        # post_enc_test.append(post_enc_positive)
        # post_enc_test.append(post_enc_negative)
        
#         print(len(feature_embeddings_train),"feature_embeddings_train")
        # Compute triplet loss
        triplet_loss = loss_fn(anchor_features, positive_features, negative_features)
        
        # triplet_loss=0
        # Forward pass for classification loss
        # print(anchor_class,"anchor_class_scores")
        # all_class_scores = torch.cat([anchor_class_scores, positive_class_scores, negative_class_scores], dim=0)
        # all_labels_train = torch.cat([anchor_class, anchor_class, negative_class], dim=0)  # Assuming the third element is the label
        # predicted_classes_train = torch.argmax(all_class_scores, dim=1)
        # print(len(all_class_scores),"all_class_scores")
        # pred_train.extend(predicted_classes_train)
        # label_train.extend(all_labels_train)
        # pred_train = torch.cat((pred_train, predicted_classes_train), dim=0)
        # label_train = torch.cat((label_train, all_labels_train), dim=0)
        # correct_predictions_train= (predicted_classes_train == all_labels)

        # accuracy_train = correct_predictions_train.sum().item() / len(all_labels)
        # print("accuracy of train", accuracy_train)
        # Compute classification loss
        # class_loss = classification_loss_fn(all_class_scores, all_labels_train)

        # Combine losses
        # Backpropagation
        total_loss = triplet_loss
        # total_loss=class_loss
        # print(class_loss,"class_loss",triplet_loss,"triplet_loss")
        total_loss.backward()
        optimizer.step()
        
        t_loss += total_loss.item()

        # Calculate training accuracy (use anchor_class_scores for classification task)
        predicted_classes_train = torch.argmax(anchor_class_scores, dim=1)
        correct_train_preds += (predicted_classes_train == anchor_class).sum().item()
        total_train_samples += len(anchor_class)

    # Average loss for the epoch
    t_loss /= len(dataloader)
    training_losses.append(t_loss)
    
#     accuracy_train = accuracy_score(all_labels_train, predicted_classes_train)
#     print("accuracy of train", accuracy_train)
    # Validation phase

    # Calculate and store training accuracy
    training_accuracy = correct_train_preds / total_train_samples
    training_accuracies.append(training_accuracy)
    print_log(f"Training Accuracy: {training_accuracy:.6f}")

    # Validation phase
    model.eval()
    v_loss = 0.0
    all_preds = []
    all_labels = []
    t_dataset = TestDataset(validation_data)
    t_dataloader = DataLoader(t_dataset, batch_size=batch_size, shuffle=False)
    correct_val_preds = 0
    total_val_samples = 0
    tot = 0
    print_log(f"The lenth of t_dataloader : {len(t_dataloader)}")
    
    for batch_idx_t, item_t in enumerate(t_dataloader):
        with torch.no_grad():
            val = tot // 992
            tot += 1
            
            item_t_in, class_label = item_t
            item_out = model(item_t_in.float())
            class_scores = item_out[0]
#             post_enc_val=item_out[2]
#             post_enc_test.append(post_enc_val)
            true_labels = class_label
            predicted_classes = torch.argmax(class_scores, dim=1)

            correct_predictions = (predicted_classes == true_labels)
            accuracy = correct_predictions.sum().item() / len(true_labels)
            
            correct_val_preds += (predicted_classes == true_labels).sum().item()
            total_val_samples += len(true_labels)
            
#             print(f"Batch {batch_idx_t} - True Labels: {true_labels.tolist()} - Predicted: {predicted_classes.tolist()} -Class Labels: {class_label}")
            all_preds.extend(predicted_classes.tolist())
            all_labels.extend(true_labels.tolist())
#             val_loss = classification_loss_fn(class_scores, true_labels)
#             v_loss += val_loss.item()
#     v_loss /= len(t_dataloader)
#     validation_losses.append(v_loss)
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    print_log(f"loop done  {tot}")
    end = time.time()
    
    print_log(f"------> Epoch No: {i+1} - Loss: {t_loss:.6f} - Accuracy: {accuracy:.6f} - Precision: {precision:.6f} - Recall: {recall:.6f} - F1: {f1:.6f} - Time: {end-start:.2f}")
#     scheduler.step(t_loss)

    # Calculate and store validation accuracy
    validation_accuracy = correct_val_preds / total_val_samples
    validation_accuracies.append(validation_accuracy)
    
    print_log(f"Validation Accuracy: {validation_accuracy:.6f}")

    # Logging and saving the best model
    print_log(f"Epoch No: {i+1} - Loss: {t_loss:.6f} - Training Accuracy: {training_accuracy:.6f} - Validation Accuracy: {validation_accuracy:.6f}")
    
    # if validation_accuracy > best_accuracy:
    #     print_log(f"Validation accuracy improved. Saving model...")
    #     best_accuracy = validation_accuracy
    #     torch.save(model, f"{best_model_save_path}/epoch_{i+1}_accuracy_{validation_accuracy:.6f}.pt")
    
    # Save model if validation loss is better
    if t_loss < best_loss:
        print_log(f"Loss improved from {best_loss:.6f} to {t_loss:.6f}. Saving model...")
        best_loss = t_loss
        torch.save(model, best_model_save_path + f"/epoch_{i+1}accuracy{accuracy}.pt")
        model_path=best_model_save_path + f"/epoch_{i+1}accuracy{accuracy}.pt"
        print_log(f"Best model is saved in model_path (by losses): {model_path}")
        saved_models.append(model_path)
        if len(saved_models) > max_saved_models:
            # Remove the oldest saved model
            oldest_model = saved_models.pop(0)
            if os.path.exists(oldest_model):
                os.remove(oldest_model)
                print_log(f"Deleted old model: {oldest_model}")
# Out:
# INFO    | Line 8   | Epoch - 1 is started
# INFO    | Line 87  | Training Accuracy: 0.121875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 1 - Loss: 0.986679 - Accuracy: 0.162228 - Precision: 0.176690 - Recall: 0.184612 - F1: 0.138888 - Time: 29.61
# INFO    | Line 141 | Validation Accuracy: 0.162228
# INFO    | Line 144 | Epoch No: 1 - Loss: 0.986679 - Training Accuracy: 0.121875 - Validation Accuracy: 0.162228
# INFO    | Line 153 | Loss improved from 1000.000000 to 0.986679. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_1accuracy0.162227956570427.pt
# INFO    | Line 8   | Epoch - 2 is started
# INFO    | Line 87  | Training Accuracy: 0.125625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 2 - Loss: 1.031025 - Accuracy: 0.152880 - Precision: 0.121733 - Recall: 0.146855 - F1: 0.117059 - Time: 28.31
# INFO    | Line 141 | Validation Accuracy: 0.152880
# INFO    | Line 144 | Epoch No: 2 - Loss: 1.031025 - Training Accuracy: 0.125625 - Validation Accuracy: 0.152880
# INFO    | Line 8   | Epoch - 3 is started
# INFO    | Line 87  | Training Accuracy: 0.125000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 3 - Loss: 1.269041 - Accuracy: 0.070111 - Precision: 0.114005 - Recall: 0.094458 - F1: 0.064033 - Time: 28.21
# INFO    | Line 141 | Validation Accuracy: 0.070111
# INFO    | Line 144 | Epoch No: 3 - Loss: 1.269041 - Training Accuracy: 0.125000 - Validation Accuracy: 0.070111
# INFO    | Line 8   | Epoch - 4 is started
# INFO    | Line 87  | Training Accuracy: 0.137500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 4 - Loss: 1.595040 - Accuracy: 0.160232 - Precision: 0.136863 - Recall: 0.168590 - F1: 0.106942 - Time: 28.19
# INFO    | Line 141 | Validation Accuracy: 0.160232
# INFO    | Line 144 | Epoch No: 4 - Loss: 1.595040 - Training Accuracy: 0.137500 - Validation Accuracy: 0.160232
# INFO    | Line 8   | Epoch - 5 is started
# INFO    | Line 87  | Training Accuracy: 0.124375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 5 - Loss: 1.002914 - Accuracy: 0.095964 - Precision: 0.133158 - Recall: 0.095705 - F1: 0.083680 - Time: 28.35
# INFO    | Line 141 | Validation Accuracy: 0.095964
# INFO    | Line 144 | Epoch No: 5 - Loss: 1.002914 - Training Accuracy: 0.124375 - Validation Accuracy: 0.095964
# INFO    | Line 8   | Epoch - 6 is started
# INFO    | Line 87  | Training Accuracy: 0.147500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 6 - Loss: 0.867934 - Accuracy: 0.197283 - Precision: 0.174094 - Recall: 0.194167 - F1: 0.136663 - Time: 28.36
# INFO    | Line 141 | Validation Accuracy: 0.197283
# INFO    | Line 144 | Epoch No: 6 - Loss: 0.867934 - Training Accuracy: 0.147500 - Validation Accuracy: 0.197283
# INFO    | Line 153 | Loss improved from 0.986679 to 0.867934. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_6accuracy0.19728321729392861.pt
# INFO    | Line 8   | Epoch - 7 is started
# INFO    | Line 87  | Training Accuracy: 0.156875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 7 - Loss: 0.822214 - Accuracy: 0.180729 - Precision: 0.182656 - Recall: 0.193644 - F1: 0.131415 - Time: 28.36
# INFO    | Line 141 | Validation Accuracy: 0.180729
# INFO    | Line 144 | Epoch No: 7 - Loss: 0.822214 - Training Accuracy: 0.156875 - Validation Accuracy: 0.180729
# INFO    | Line 153 | Loss improved from 0.867934 to 0.822214. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_7accuracy0.1807293441744973.pt
# INFO    | Line 8   | Epoch - 8 is started
# INFO    | Line 87  | Training Accuracy: 0.151250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 8 - Loss: 0.827382 - Accuracy: 0.200302 - Precision: 0.196553 - Recall: 0.212637 - F1: 0.163690 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.200302
# INFO    | Line 144 | Epoch No: 8 - Loss: 0.827382 - Training Accuracy: 0.151250 - Validation Accuracy: 0.200302
# INFO    | Line 8   | Epoch - 9 is started
# INFO    | Line 87  | Training Accuracy: 0.162500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 9 - Loss: 0.849230 - Accuracy: 0.109694 - Precision: 0.128141 - Recall: 0.124172 - F1: 0.113011 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.109694
# INFO    | Line 144 | Epoch No: 9 - Loss: 0.849230 - Training Accuracy: 0.162500 - Validation Accuracy: 0.109694
# INFO    | Line 8   | Epoch - 10 is started
# INFO    | Line 87  | Training Accuracy: 0.149375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 10 - Loss: 0.758029 - Accuracy: 0.179220 - Precision: 0.167580 - Recall: 0.177208 - F1: 0.122840 - Time: 28.12
# INFO    | Line 141 | Validation Accuracy: 0.179220
# INFO    | Line 144 | Epoch No: 10 - Loss: 0.758029 - Training Accuracy: 0.149375 - Validation Accuracy: 0.179220
# INFO    | Line 153 | Loss improved from 0.822214 to 0.758029. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_10accuracy0.1792200204489021.pt
# INFO    | Line 8   | Epoch - 11 is started
# INFO    | Line 87  | Training Accuracy: 0.150625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 11 - Loss: 0.780221 - Accuracy: 0.191587 - Precision: 0.183044 - Recall: 0.221668 - F1: 0.146128 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.191587
# INFO    | Line 144 | Epoch No: 11 - Loss: 0.780221 - Training Accuracy: 0.150625 - Validation Accuracy: 0.191587
# INFO    | Line 8   | Epoch - 12 is started
# INFO    | Line 87  | Training Accuracy: 0.156250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 12 - Loss: 0.773677 - Accuracy: 0.138371 - Precision: 0.113287 - Recall: 0.195817 - F1: 0.114601 - Time: 28.11
# INFO    | Line 141 | Validation Accuracy: 0.138371
# INFO    | Line 144 | Epoch No: 12 - Loss: 0.773677 - Training Accuracy: 0.156250 - Validation Accuracy: 0.138371
# INFO    | Line 8   | Epoch - 13 is started
# INFO    | Line 87  | Training Accuracy: 0.170000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 13 - Loss: 0.753875 - Accuracy: 0.137592 - Precision: 0.118067 - Recall: 0.193168 - F1: 0.112411 - Time: 28.15
# INFO    | Line 141 | Validation Accuracy: 0.137592
# INFO    | Line 144 | Epoch No: 13 - Loss: 0.753875 - Training Accuracy: 0.170000 - Validation Accuracy: 0.137592
# INFO    | Line 153 | Loss improved from 0.758029 to 0.753875. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_13accuracy0.1375918983397439.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_1accuracy0.162227956570427.pt
# INFO    | Line 8   | Epoch - 14 is started
# INFO    | Line 87  | Training Accuracy: 0.159375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 14 - Loss: 0.810953 - Accuracy: 0.176445 - Precision: 0.140506 - Recall: 0.226841 - F1: 0.122379 - Time: 28.09
# INFO    | Line 141 | Validation Accuracy: 0.176445
# INFO    | Line 144 | Epoch No: 14 - Loss: 0.810953 - Training Accuracy: 0.159375 - Validation Accuracy: 0.176445
# INFO    | Line 8   | Epoch - 15 is started
# INFO    | Line 87  | Training Accuracy: 0.162500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 15 - Loss: 0.751954 - Accuracy: 0.179853 - Precision: 0.146720 - Recall: 0.194420 - F1: 0.117715 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.179853
# INFO    | Line 144 | Epoch No: 15 - Loss: 0.751954 - Training Accuracy: 0.162500 - Validation Accuracy: 0.179853
# INFO    | Line 153 | Loss improved from 0.753875 to 0.751954. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_15accuracy0.17985296265640976.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_6accuracy0.19728321729392861.pt
# INFO    | Line 8   | Epoch - 16 is started
# INFO    | Line 87  | Training Accuracy: 0.173125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 16 - Loss: 0.719802 - Accuracy: 0.146697 - Precision: 0.120369 - Recall: 0.149694 - F1: 0.090932 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.146697
# INFO    | Line 144 | Epoch No: 16 - Loss: 0.719802 - Training Accuracy: 0.173125 - Validation Accuracy: 0.146697
# INFO    | Line 153 | Loss improved from 0.751954 to 0.719802. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_16accuracy0.14669652855543114.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_7accuracy0.1807293441744973.pt
# INFO    | Line 8   | Epoch - 17 is started
# INFO    | Line 87  | Training Accuracy: 0.144375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 17 - Loss: 0.699193 - Accuracy: 0.141730 - Precision: 0.128959 - Recall: 0.132433 - F1: 0.083810 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.141730
# INFO    | Line 144 | Epoch No: 17 - Loss: 0.699193 - Training Accuracy: 0.144375 - Validation Accuracy: 0.141730
# INFO    | Line 153 | Loss improved from 0.719802 to 0.699193. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_17accuracy0.14173036661960173.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_10accuracy0.1792200204489021.pt
# INFO    | Line 8   | Epoch - 18 is started
# INFO    | Line 87  | Training Accuracy: 0.122500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 18 - Loss: 0.747287 - Accuracy: 0.140367 - Precision: 0.112937 - Recall: 0.129064 - F1: 0.078236 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.140367
# INFO    | Line 144 | Epoch No: 18 - Loss: 0.747287 - Training Accuracy: 0.122500 - Validation Accuracy: 0.140367
# INFO    | Line 8   | Epoch - 19 is started
# INFO    | Line 87  | Training Accuracy: 0.131875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 19 - Loss: 0.682788 - Accuracy: 0.134622 - Precision: 0.119370 - Recall: 0.125642 - F1: 0.073007 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.134622
# INFO    | Line 144 | Epoch No: 19 - Loss: 0.682788 - Training Accuracy: 0.131875 - Validation Accuracy: 0.134622
# INFO    | Line 153 | Loss improved from 0.699193 to 0.682788. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_19accuracy0.13462193875066947.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_13accuracy0.1375918983397439.pt
# INFO    | Line 8   | Epoch - 20 is started
# INFO    | Line 87  | Training Accuracy: 0.113750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 20 - Loss: 0.812198 - Accuracy: 0.132480 - Precision: 0.125479 - Recall: 0.128237 - F1: 0.069843 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.132480
# INFO    | Line 144 | Epoch No: 20 - Loss: 0.812198 - Training Accuracy: 0.113750 - Validation Accuracy: 0.132480
# INFO    | Line 8   | Epoch - 21 is started
# INFO    | Line 87  | Training Accuracy: 0.123125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 21 - Loss: 0.705141 - Accuracy: 0.147281 - Precision: 0.147504 - Recall: 0.144332 - F1: 0.078546 - Time: 28.06
# INFO    | Line 141 | Validation Accuracy: 0.147281
# INFO    | Line 144 | Epoch No: 21 - Loss: 0.705141 - Training Accuracy: 0.123125 - Validation Accuracy: 0.147281
# INFO    | Line 8   | Epoch - 22 is started
# INFO    | Line 87  | Training Accuracy: 0.155625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 22 - Loss: 0.744782 - Accuracy: 0.145918 - Precision: 0.125006 - Recall: 0.132699 - F1: 0.075624 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.145918
# INFO    | Line 144 | Epoch No: 22 - Loss: 0.744782 - Training Accuracy: 0.155625 - Validation Accuracy: 0.145918
# INFO    | Line 8   | Epoch - 23 is started
# INFO    | Line 87  | Training Accuracy: 0.148125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 23 - Loss: 0.769334 - Accuracy: 0.142753 - Precision: 0.078823 - Recall: 0.130494 - F1: 0.073325 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.142753
# INFO    | Line 144 | Epoch No: 23 - Loss: 0.769334 - Training Accuracy: 0.148125 - Validation Accuracy: 0.142753
# INFO    | Line 8   | Epoch - 24 is started
# INFO    | Line 87  | Training Accuracy: 0.146875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 24 - Loss: 0.703821 - Accuracy: 0.142217 - Precision: 0.099947 - Recall: 0.131315 - F1: 0.078128 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.142217
# INFO    | Line 144 | Epoch No: 24 - Loss: 0.703821 - Training Accuracy: 0.146875 - Validation Accuracy: 0.142217
# INFO    | Line 8   | Epoch - 25 is started
# INFO    | Line 87  | Training Accuracy: 0.127500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 25 - Loss: 0.668101 - Accuracy: 0.136813 - Precision: 0.060325 - Recall: 0.130920 - F1: 0.069800 - Time: 28.03
# INFO    | Line 141 | Validation Accuracy: 0.136813
# INFO    | Line 144 | Epoch No: 25 - Loss: 0.668101 - Training Accuracy: 0.127500 - Validation Accuracy: 0.136813
# INFO    | Line 153 | Loss improved from 0.682788 to 0.668101. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_25accuracy0.1368128925458883.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_15accuracy0.17985296265640976.pt
# INFO    | Line 8   | Epoch - 26 is started
# INFO    | Line 87  | Training Accuracy: 0.139375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 26 - Loss: 0.693049 - Accuracy: 0.142607 - Precision: 0.171410 - Recall: 0.142184 - F1: 0.076724 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.142607
# INFO    | Line 144 | Epoch No: 26 - Loss: 0.693049 - Training Accuracy: 0.139375 - Validation Accuracy: 0.142607
# INFO    | Line 8   | Epoch - 27 is started
# INFO    | Line 87  | Training Accuracy: 0.133750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 27 - Loss: 0.645393 - Accuracy: 0.138079 - Precision: 0.116958 - Recall: 0.143646 - F1: 0.080554 - Time: 28.03
# INFO    | Line 141 | Validation Accuracy: 0.138079
# INFO    | Line 144 | Epoch No: 27 - Loss: 0.645393 - Training Accuracy: 0.133750 - Validation Accuracy: 0.138079
# INFO    | Line 153 | Loss improved from 0.668101 to 0.645393. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_27accuracy0.13807877696090365.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_16accuracy0.14669652855543114.pt
# INFO    | Line 8   | Epoch - 28 is started
# INFO    | Line 87  | Training Accuracy: 0.136875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 28 - Loss: 0.652308 - Accuracy: 0.141730 - Precision: 0.140086 - Recall: 0.144605 - F1: 0.088041 - Time: 28.03
# INFO    | Line 141 | Validation Accuracy: 0.141730
# INFO    | Line 144 | Epoch No: 28 - Loss: 0.652308 - Training Accuracy: 0.136875 - Validation Accuracy: 0.141730
# INFO    | Line 8   | Epoch - 29 is started
# INFO    | Line 87  | Training Accuracy: 0.144375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 29 - Loss: 0.671352 - Accuracy: 0.150543 - Precision: 0.140275 - Recall: 0.142957 - F1: 0.099718 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.150543
# INFO    | Line 144 | Epoch No: 29 - Loss: 0.671352 - Training Accuracy: 0.144375 - Validation Accuracy: 0.150543
# INFO    | Line 8   | Epoch - 30 is started
# INFO    | Line 87  | Training Accuracy: 0.135000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 30 - Loss: 0.647070 - Accuracy: 0.139734 - Precision: 0.117301 - Recall: 0.126868 - F1: 0.080644 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.139734
# INFO    | Line 144 | Epoch No: 30 - Loss: 0.647070 - Training Accuracy: 0.135000 - Validation Accuracy: 0.139734
# INFO    | Line 8   | Epoch - 31 is started
# INFO    | Line 87  | Training Accuracy: 0.150625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 31 - Loss: 0.728731 - Accuracy: 0.150153 - Precision: 0.116276 - Recall: 0.144637 - F1: 0.102336 - Time: 28.06
# INFO    | Line 141 | Validation Accuracy: 0.150153
# INFO    | Line 144 | Epoch No: 31 - Loss: 0.728731 - Training Accuracy: 0.150625 - Validation Accuracy: 0.150153
# INFO    | Line 8   | Epoch - 32 is started
# INFO    | Line 87  | Training Accuracy: 0.148125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 32 - Loss: 0.678082 - Accuracy: 0.172891 - Precision: 0.164410 - Recall: 0.194597 - F1: 0.142815 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.172891
# INFO    | Line 144 | Epoch No: 32 - Loss: 0.678082 - Training Accuracy: 0.148125 - Validation Accuracy: 0.172891
# INFO    | Line 8   | Epoch - 33 is started
# INFO    | Line 87  | Training Accuracy: 0.153125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 33 - Loss: 0.653555 - Accuracy: 0.161059 - Precision: 0.143543 - Recall: 0.169387 - F1: 0.120963 - Time: 27.99
# INFO    | Line 141 | Validation Accuracy: 0.161059
# INFO    | Line 144 | Epoch No: 33 - Loss: 0.653555 - Training Accuracy: 0.153125 - Validation Accuracy: 0.161059
# INFO    | Line 8   | Epoch - 34 is started
# INFO    | Line 87  | Training Accuracy: 0.138125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 34 - Loss: 0.700880 - Accuracy: 0.154000 - Precision: 0.142157 - Recall: 0.167518 - F1: 0.129867 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.154000
# INFO    | Line 144 | Epoch No: 34 - Loss: 0.700880 - Training Accuracy: 0.138125 - Validation Accuracy: 0.154000
# INFO    | Line 8   | Epoch - 35 is started
# INFO    | Line 87  | Training Accuracy: 0.140625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 35 - Loss: 0.666853 - Accuracy: 0.132236 - Precision: 0.120069 - Recall: 0.125491 - F1: 0.100056 - Time: 28.03
# INFO    | Line 141 | Validation Accuracy: 0.132236
# INFO    | Line 144 | Epoch No: 35 - Loss: 0.666853 - Training Accuracy: 0.140625 - Validation Accuracy: 0.132236
# INFO    | Line 8   | Epoch - 36 is started
# INFO    | Line 87  | Training Accuracy: 0.133750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 36 - Loss: 0.658595 - Accuracy: 0.126686 - Precision: 0.131146 - Recall: 0.126981 - F1: 0.104724 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.126686
# INFO    | Line 144 | Epoch No: 36 - Loss: 0.658595 - Training Accuracy: 0.133750 - Validation Accuracy: 0.126686
# INFO    | Line 8   | Epoch - 37 is started
# INFO    | Line 87  | Training Accuracy: 0.120625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 37 - Loss: 0.619053 - Accuracy: 0.136813 - Precision: 0.136433 - Recall: 0.138723 - F1: 0.115941 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.136813
# INFO    | Line 144 | Epoch No: 37 - Loss: 0.619053 - Training Accuracy: 0.120625 - Validation Accuracy: 0.136813
# INFO    | Line 153 | Loss improved from 0.645393 to 0.619053. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_37accuracy0.1368128925458883.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_17accuracy0.14173036661960173.pt
# INFO    | Line 8   | Epoch - 38 is started
# INFO    | Line 87  | Training Accuracy: 0.125625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 38 - Loss: 0.630699 - Accuracy: 0.133405 - Precision: 0.142375 - Recall: 0.137510 - F1: 0.117275 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.133405
# INFO    | Line 144 | Epoch No: 38 - Loss: 0.630699 - Training Accuracy: 0.125625 - Validation Accuracy: 0.133405
# INFO    | Line 8   | Epoch - 39 is started
# INFO    | Line 87  | Training Accuracy: 0.128125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 39 - Loss: 0.619965 - Accuracy: 0.130873 - Precision: 0.147999 - Recall: 0.132018 - F1: 0.118415 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.130873
# INFO    | Line 144 | Epoch No: 39 - Loss: 0.619965 - Training Accuracy: 0.128125 - Validation Accuracy: 0.130873
# INFO    | Line 8   | Epoch - 40 is started
# INFO    | Line 87  | Training Accuracy: 0.118750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 40 - Loss: 0.604651 - Accuracy: 0.135596 - Precision: 0.136596 - Recall: 0.163551 - F1: 0.135648 - Time: 28.03
# INFO    | Line 141 | Validation Accuracy: 0.135596
# INFO    | Line 144 | Epoch No: 40 - Loss: 0.604651 - Training Accuracy: 0.118750 - Validation Accuracy: 0.135596
# INFO    | Line 153 | Loss improved from 0.619053 to 0.604651. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_40accuracy0.13559569599298896.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_19accuracy0.13462193875066947.pt
# INFO    | Line 8   | Epoch - 41 is started
# INFO    | Line 87  | Training Accuracy: 0.134375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 41 - Loss: 0.618751 - Accuracy: 0.163835 - Precision: 0.131212 - Recall: 0.184649 - F1: 0.130820 - Time: 28.00
# INFO    | Line 141 | Validation Accuracy: 0.163835
# INFO    | Line 144 | Epoch No: 41 - Loss: 0.618751 - Training Accuracy: 0.134375 - Validation Accuracy: 0.163835
# INFO    | Line 8   | Epoch - 42 is started
# INFO    | Line 87  | Training Accuracy: 0.129375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 42 - Loss: 0.594456 - Accuracy: 0.123570 - Precision: 0.089521 - Recall: 0.114133 - F1: 0.086264 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.123570
# INFO    | Line 144 | Epoch No: 42 - Loss: 0.594456 - Training Accuracy: 0.129375 - Validation Accuracy: 0.123570
# INFO    | Line 153 | Loss improved from 0.604651 to 0.594456. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_42accuracy0.12356979405034325.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_25accuracy0.1368128925458883.pt
# INFO    | Line 8   | Epoch - 43 is started
# INFO    | Line 87  | Training Accuracy: 0.116875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 43 - Loss: 0.665124 - Accuracy: 0.148790 - Precision: 0.112621 - Recall: 0.152637 - F1: 0.107739 - Time: 28.06
# INFO    | Line 141 | Validation Accuracy: 0.148790
# INFO    | Line 144 | Epoch No: 43 - Loss: 0.665124 - Training Accuracy: 0.116875 - Validation Accuracy: 0.148790
# INFO    | Line 8   | Epoch - 44 is started
# INFO    | Line 87  | Training Accuracy: 0.126250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 44 - Loss: 0.602891 - Accuracy: 0.163640 - Precision: 0.126428 - Recall: 0.189489 - F1: 0.128135 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.163640
# INFO    | Line 144 | Epoch No: 44 - Loss: 0.602891 - Training Accuracy: 0.126250 - Validation Accuracy: 0.163640
# INFO    | Line 8   | Epoch - 45 is started
# INFO    | Line 87  | Training Accuracy: 0.119375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 45 - Loss: 0.631076 - Accuracy: 0.127611 - Precision: 0.104318 - Recall: 0.135294 - F1: 0.112260 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.127611
# INFO    | Line 144 | Epoch No: 45 - Loss: 0.631076 - Training Accuracy: 0.119375 - Validation Accuracy: 0.127611
# INFO    | Line 8   | Epoch - 46 is started
# INFO    | Line 87  | Training Accuracy: 0.137500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 46 - Loss: 0.587805 - Accuracy: 0.140757 - Precision: 0.125374 - Recall: 0.162538 - F1: 0.130959 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.140757
# INFO    | Line 144 | Epoch No: 46 - Loss: 0.587805 - Training Accuracy: 0.137500 - Validation Accuracy: 0.140757
# INFO    | Line 153 | Loss improved from 0.594456 to 0.587805. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_46accuracy0.14075660937728224.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_27accuracy0.13807877696090365.pt
# INFO    | Line 8   | Epoch - 47 is started
# INFO    | Line 87  | Training Accuracy: 0.150625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 47 - Loss: 0.584264 - Accuracy: 0.133843 - Precision: 0.116025 - Recall: 0.170499 - F1: 0.124396 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.133843
# INFO    | Line 144 | Epoch No: 47 - Loss: 0.584264 - Training Accuracy: 0.150625 - Validation Accuracy: 0.133843
# INFO    | Line 153 | Loss improved from 0.587805 to 0.584264. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_47accuracy0.13384293295681388.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_37accuracy0.1368128925458883.pt
# INFO    | Line 8   | Epoch - 48 is started
# INFO    | Line 87  | Training Accuracy: 0.142500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 48 - Loss: 0.618785 - Accuracy: 0.115049 - Precision: 0.135495 - Recall: 0.144516 - F1: 0.103835 - Time: 28.09
# INFO    | Line 141 | Validation Accuracy: 0.115049
# INFO    | Line 144 | Epoch No: 48 - Loss: 0.618785 - Training Accuracy: 0.142500 - Validation Accuracy: 0.115049
# INFO    | Line 8   | Epoch - 49 is started
# INFO    | Line 87  | Training Accuracy: 0.149375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 49 - Loss: 0.560401 - Accuracy: 0.115439 - Precision: 0.072843 - Recall: 0.158773 - F1: 0.084300 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.115439
# INFO    | Line 144 | Epoch No: 49 - Loss: 0.560401 - Training Accuracy: 0.149375 - Validation Accuracy: 0.115439
# INFO    | Line 153 | Loss improved from 0.584264 to 0.560401. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_49accuracy0.11543892107697551.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_40accuracy0.13559569599298896.pt
# INFO    | Line 8   | Epoch - 50 is started
# INFO    | Line 87  | Training Accuracy: 0.148125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 50 - Loss: 0.622971 - Accuracy: 0.111739 - Precision: 0.104323 - Recall: 0.149525 - F1: 0.092570 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.111739
# INFO    | Line 144 | Epoch No: 50 - Loss: 0.622971 - Training Accuracy: 0.148125 - Validation Accuracy: 0.111739
# INFO    | Line 8   | Epoch - 51 is started
# INFO    | Line 87  | Training Accuracy: 0.134375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 51 - Loss: 0.598992 - Accuracy: 0.101417 - Precision: 0.081359 - Recall: 0.100736 - F1: 0.070991 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.101417
# INFO    | Line 144 | Epoch No: 51 - Loss: 0.598992 - Training Accuracy: 0.134375 - Validation Accuracy: 0.101417
# INFO    | Line 8   | Epoch - 52 is started
# INFO    | Line 87  | Training Accuracy: 0.130000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 52 - Loss: 0.588643 - Accuracy: 0.109840 - Precision: 0.139414 - Recall: 0.107313 - F1: 0.083021 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.109840
# INFO    | Line 144 | Epoch No: 52 - Loss: 0.588643 - Training Accuracy: 0.130000 - Validation Accuracy: 0.109840
# INFO    | Line 8   | Epoch - 53 is started
# INFO    | Line 87  | Training Accuracy: 0.148125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 53 - Loss: 0.642803 - Accuracy: 0.109061 - Precision: 0.102324 - Recall: 0.100711 - F1: 0.068948 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.109061
# INFO    | Line 144 | Epoch No: 53 - Loss: 0.642803 - Training Accuracy: 0.148125 - Validation Accuracy: 0.109061
# INFO    | Line 8   | Epoch - 54 is started
# INFO    | Line 87  | Training Accuracy: 0.140625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 54 - Loss: 0.609545 - Accuracy: 0.093140 - Precision: 0.076816 - Recall: 0.086253 - F1: 0.058871 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.093140
# INFO    | Line 144 | Epoch No: 54 - Loss: 0.609545 - Training Accuracy: 0.140625 - Validation Accuracy: 0.093140
# INFO    | Line 8   | Epoch - 55 is started
# INFO    | Line 87  | Training Accuracy: 0.148750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 55 - Loss: 0.575850 - Accuracy: 0.113199 - Precision: 0.036186 - Recall: 0.104653 - F1: 0.049898 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.113199
# INFO    | Line 144 | Epoch No: 55 - Loss: 0.575850 - Training Accuracy: 0.148750 - Validation Accuracy: 0.113199
# INFO    | Line 8   | Epoch - 56 is started
# INFO    | Line 87  | Training Accuracy: 0.160000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 56 - Loss: 0.564261 - Accuracy: 0.110814 - Precision: 0.066783 - Recall: 0.113161 - F1: 0.070025 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.110814
# INFO    | Line 144 | Epoch No: 56 - Loss: 0.564261 - Training Accuracy: 0.160000 - Validation Accuracy: 0.110814
# INFO    | Line 8   | Epoch - 57 is started
# INFO    | Line 87  | Training Accuracy: 0.157500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 57 - Loss: 0.544519 - Accuracy: 0.097570 - Precision: 0.050909 - Recall: 0.095471 - F1: 0.053278 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.097570
# INFO    | Line 144 | Epoch No: 57 - Loss: 0.544519 - Training Accuracy: 0.157500 - Validation Accuracy: 0.097570
# INFO    | Line 153 | Loss improved from 0.560401 to 0.544519. Saving model...
# INFO    | Line 157 | Best model is saved in model_path (by losses): /kaggle/working/best_models/epoch_57accuracy0.09757047568041287.pt
# INFO    | Line 164 | Deleted old model: /kaggle/working/best_models/epoch_42accuracy0.12356979405034325.pt
# INFO    | Line 8   | Epoch - 58 is started
# INFO    | Line 87  | Training Accuracy: 0.128750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 58 - Loss: 0.609810 - Accuracy: 0.104971 - Precision: 0.044963 - Recall: 0.098960 - F1: 0.055192 - Time: 28.00
# INFO    | Line 141 | Validation Accuracy: 0.104971
# INFO    | Line 144 | Epoch No: 58 - Loss: 0.609810 - Training Accuracy: 0.128750 - Validation Accuracy: 0.104971
# INFO    | Line 8   | Epoch - 59 is started
# INFO    | Line 87  | Training Accuracy: 0.121250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 59 - Loss: 0.726803 - Accuracy: 0.095039 - Precision: 0.056305 - Recall: 0.096217 - F1: 0.060145 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.095039
# INFO    | Line 144 | Epoch No: 59 - Loss: 0.726803 - Training Accuracy: 0.121250 - Validation Accuracy: 0.095039
# INFO    | Line 8   | Epoch - 60 is started
# INFO    | Line 87  | Training Accuracy: 0.129375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 60 - Loss: 0.657245 - Accuracy: 0.128633 - Precision: 0.057280 - Recall: 0.127591 - F1: 0.075290 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.128633
# INFO    | Line 144 | Epoch No: 60 - Loss: 0.657245 - Training Accuracy: 0.129375 - Validation Accuracy: 0.128633
# INFO    | Line 8   | Epoch - 61 is started
# INFO    | Line 87  | Training Accuracy: 0.163750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 61 - Loss: 0.665289 - Accuracy: 0.140221 - Precision: 0.094209 - Recall: 0.149892 - F1: 0.097726 - Time: 28.03
# INFO    | Line 141 | Validation Accuracy: 0.140221
# INFO    | Line 144 | Epoch No: 61 - Loss: 0.665289 - Training Accuracy: 0.163750 - Validation Accuracy: 0.140221
# INFO    | Line 8   | Epoch - 62 is started
# INFO    | Line 87  | Training Accuracy: 0.168125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 62 - Loss: 0.611377 - Accuracy: 0.148108 - Precision: 0.101069 - Recall: 0.136636 - F1: 0.078424 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.148108
# INFO    | Line 144 | Epoch No: 62 - Loss: 0.611377 - Training Accuracy: 0.168125 - Validation Accuracy: 0.148108
# INFO    | Line 8   | Epoch - 63 is started
# INFO    | Line 87  | Training Accuracy: 0.170000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 63 - Loss: 0.619004 - Accuracy: 0.153367 - Precision: 0.127688 - Recall: 0.149661 - F1: 0.095799 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.153367
# INFO    | Line 144 | Epoch No: 63 - Loss: 0.619004 - Training Accuracy: 0.170000 - Validation Accuracy: 0.153367
# INFO    | Line 8   | Epoch - 64 is started
# INFO    | Line 87  | Training Accuracy: 0.148750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 64 - Loss: 0.613718 - Accuracy: 0.126735 - Precision: 0.142821 - Recall: 0.140922 - F1: 0.110617 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.126735
# INFO    | Line 144 | Epoch No: 64 - Loss: 0.613718 - Training Accuracy: 0.148750 - Validation Accuracy: 0.126735
# INFO    | Line 8   | Epoch - 65 is started
# INFO    | Line 87  | Training Accuracy: 0.165625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 65 - Loss: 0.568899 - Accuracy: 0.165733 - Precision: 0.112648 - Recall: 0.174763 - F1: 0.114047 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.165733
# INFO    | Line 144 | Epoch No: 65 - Loss: 0.568899 - Training Accuracy: 0.165625 - Validation Accuracy: 0.165733
# INFO    | Line 8   | Epoch - 66 is started
# INFO    | Line 87  | Training Accuracy: 0.147500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 66 - Loss: 0.564300 - Accuracy: 0.128439 - Precision: 0.149660 - Recall: 0.129430 - F1: 0.093229 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.128439
# INFO    | Line 144 | Epoch No: 66 - Loss: 0.564300 - Training Accuracy: 0.147500 - Validation Accuracy: 0.128439
# INFO    | Line 8   | Epoch - 67 is started
# INFO    | Line 87  | Training Accuracy: 0.153125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# INFO    | Line 144 | Epoch No: 80 - Loss: 0.566292 - Training Accuracy: 0.116250 - Validation Accuracy: 0.087443
# INFO    | Line 8   | Epoch - 81 is started
# INFO    | Line 87  | Training Accuracy: 0.120000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 81 - Loss: 0.544585 - Accuracy: 0.084133 - Precision: 0.127435 - Recall: 0.078806 - F1: 0.038307 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.084133
# INFO    | Line 144 | Epoch No: 81 - Loss: 0.544585 - Training Accuracy: 0.120000 - Validation Accuracy: 0.084133
# INFO    | Line 8   | Epoch - 82 is started
# INFO    | Line 87  | Training Accuracy: 0.120625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 82 - Loss: 0.566888 - Accuracy: 0.077268 - Precision: 0.032477 - Recall: 0.071816 - F1: 0.034466 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.077268
# INFO    | Line 144 | Epoch No: 82 - Loss: 0.566888 - Training Accuracy: 0.120625 - Validation Accuracy: 0.077268
# INFO    | Line 8   | Epoch - 83 is started
# INFO    | Line 87  | Training Accuracy: 0.130625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 83 - Loss: 0.531486 - Accuracy: 0.082380 - Precision: 0.034229 - Recall: 0.076330 - F1: 0.040197 - Time: 28.12
# INFO    | Line 141 | Validation Accuracy: 0.082380
# INFO    | Line 144 | Epoch No: 83 - Loss: 0.531486 - Training Accuracy: 0.130625 - Validation Accuracy: 0.082380
# INFO    | Line 8   | Epoch - 84 is started
# INFO    | Line 87  | Training Accuracy: 0.111250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 84 - Loss: 0.542493 - Accuracy: 0.082234 - Precision: 0.028431 - Recall: 0.076510 - F1: 0.033610 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.082234
# INFO    | Line 144 | Epoch No: 84 - Loss: 0.542493 - Training Accuracy: 0.111250 - Validation Accuracy: 0.082234
# INFO    | Line 8   | Epoch - 85 is started
# INFO    | Line 87  | Training Accuracy: 0.114375
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 85 - Loss: 0.519964 - Accuracy: 0.089683 - Precision: 0.036398 - Recall: 0.083125 - F1: 0.042626 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.089683
# INFO    | Line 144 | Epoch No: 85 - Loss: 0.519964 - Training Accuracy: 0.114375 - Validation Accuracy: 0.089683
# INFO    | Line 8   | Epoch - 86 is started
# INFO    | Line 87  | Training Accuracy: 0.125625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 86 - Loss: 0.546902 - Accuracy: 0.067725 - Precision: 0.028855 - Recall: 0.062899 - F1: 0.031804 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.067725
# INFO    | Line 144 | Epoch No: 86 - Loss: 0.546902 - Training Accuracy: 0.125625 - Validation Accuracy: 0.067725
# INFO    | Line 8   | Epoch - 87 is started
# INFO    | Line 87  | Training Accuracy: 0.133750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 87 - Loss: 0.520857 - Accuracy: 0.114660 - Precision: 0.041517 - Recall: 0.105269 - F1: 0.057193 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.114660
# INFO    | Line 144 | Epoch No: 87 - Loss: 0.520857 - Training Accuracy: 0.133750 - Validation Accuracy: 0.114660
# INFO    | Line 8   | Epoch - 88 is started
# INFO    | Line 87  | Training Accuracy: 0.155625
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 88 - Loss: 0.555767 - Accuracy: 0.101417 - Precision: 0.039450 - Recall: 0.093553 - F1: 0.050839 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.101417
# INFO    | Line 144 | Epoch No: 88 - Loss: 0.555767 - Training Accuracy: 0.155625 - Validation Accuracy: 0.101417
# INFO    | Line 8   | Epoch - 89 is started
# INFO    | Line 87  | Training Accuracy: 0.125000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 89 - Loss: 0.528495 - Accuracy: 0.096694 - Precision: 0.036787 - Recall: 0.089622 - F1: 0.044608 - Time: 28.08
# INFO    | Line 141 | Validation Accuracy: 0.096694
# INFO    | Line 144 | Epoch No: 89 - Loss: 0.528495 - Training Accuracy: 0.125000 - Validation Accuracy: 0.096694
# INFO    | Line 8   | Epoch - 90 is started
# INFO    | Line 87  | Training Accuracy: 0.118125
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 90 - Loss: 0.905257 - Accuracy: 0.162131 - Precision: 0.093101 - Recall: 0.149775 - F1: 0.073754 - Time: 28.11
# INFO    | Line 141 | Validation Accuracy: 0.162131
# INFO    | Line 144 | Epoch No: 90 - Loss: 0.905257 - Training Accuracy: 0.118125 - Validation Accuracy: 0.162131
# INFO    | Line 8   | Epoch - 91 is started
# INFO    | Line 87  | Training Accuracy: 0.116875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 91 - Loss: 0.831258 - Accuracy: 0.140562 - Precision: 0.190803 - Recall: 0.129028 - F1: 0.062643 - Time: 28.07
# INFO    | Line 141 | Validation Accuracy: 0.140562
# INFO    | Line 144 | Epoch No: 91 - Loss: 0.831258 - Training Accuracy: 0.116875 - Validation Accuracy: 0.140562
# INFO    | Line 8   | Epoch - 92 is started
# INFO    | Line 87  | Training Accuracy: 0.116875
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 92 - Loss: 0.808320 - Accuracy: 0.136375 - Precision: 0.145619 - Recall: 0.124645 - F1: 0.060566 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.136375
# INFO    | Line 144 | Epoch No: 92 - Loss: 0.808320 - Training Accuracy: 0.116875 - Validation Accuracy: 0.136375
# INFO    | Line 8   | Epoch - 93 is started
# INFO    | Line 87  | Training Accuracy: 0.112500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 93 - Loss: 0.832077 - Accuracy: 0.116948 - Precision: 0.049626 - Recall: 0.107140 - F1: 0.058945 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.116948
# INFO    | Line 144 | Epoch No: 93 - Loss: 0.832077 - Training Accuracy: 0.112500 - Validation Accuracy: 0.116948
# INFO    | Line 8   | Epoch - 94 is started
# INFO    | Line 87  | Training Accuracy: 0.121250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 94 - Loss: 0.789300 - Accuracy: 0.126588 - Precision: 0.149809 - Recall: 0.115443 - F1: 0.057596 - Time: 28.00
# INFO    | Line 141 | Validation Accuracy: 0.126588
# INFO    | Line 144 | Epoch No: 94 - Loss: 0.789300 - Training Accuracy: 0.121250 - Validation Accuracy: 0.126588
# INFO    | Line 8   | Epoch - 95 is started
# INFO    | Line 87  | Training Accuracy: 0.112500
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 95 - Loss: 0.746069 - Accuracy: 0.135109 - Precision: 0.046431 - Recall: 0.124083 - F1: 0.066588 - Time: 28.02
# INFO    | Line 141 | Validation Accuracy: 0.135109
# INFO    | Line 144 | Epoch No: 95 - Loss: 0.746069 - Training Accuracy: 0.112500 - Validation Accuracy: 0.135109
# INFO    | Line 8   | Epoch - 96 is started
# INFO    | Line 87  | Training Accuracy: 0.125000
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 96 - Loss: 0.843784 - Accuracy: 0.147086 - Precision: 0.129818 - Recall: 0.135143 - F1: 0.068978 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.147086
# INFO    | Line 144 | Epoch No: 96 - Loss: 0.843784 - Training Accuracy: 0.125000 - Validation Accuracy: 0.147086
# INFO    | Line 8   | Epoch - 97 is started
# INFO    | Line 87  | Training Accuracy: 0.111250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 97 - Loss: 0.616936 - Accuracy: 0.096986 - Precision: 0.153182 - Recall: 0.090156 - F1: 0.041070 - Time: 28.04
# INFO    | Line 141 | Validation Accuracy: 0.096986
# INFO    | Line 144 | Epoch No: 97 - Loss: 0.616936 - Training Accuracy: 0.111250 - Validation Accuracy: 0.096986
# INFO    | Line 8   | Epoch - 98 is started
# INFO    | Line 87  | Training Accuracy: 0.116250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 98 - Loss: 0.524231 - Accuracy: 0.087005 - Precision: 0.082743 - Recall: 0.080829 - F1: 0.040210 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.087005
# INFO    | Line 144 | Epoch No: 98 - Loss: 0.524231 - Training Accuracy: 0.116250 - Validation Accuracy: 0.087005
# INFO    | Line 8   | Epoch - 99 is started
# INFO    | Line 87  | Training Accuracy: 0.101250
# INFO    | Line 99  | The lenth of t_dataloader : 642
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 99 - Loss: 0.534146 - Accuracy: 0.102488 - Precision: 0.065498 - Recall: 0.095033 - F1: 0.048850 - Time: 28.05
# INFO    | Line 141 | Validation Accuracy: 0.102488
# INFO    | Line 144 | Epoch No: 99 - Loss: 0.534146 - Training Accuracy: 0.101250 - Validation Accuracy: 0.102488
# INFO    | Line 8   | Epoch - 100 is started
# INFO    | Line 87  | Training Accuracy: 0.118750
# INFO    | Line 99  | The lenth of t_dataloader : 642
# INFO    | Line 131 | loop done  642
# INFO    | Line 134 | ------> Epoch No: 100 - Loss: 0.514837 - Accuracy: 0.115731 - Precision: 0.042598 - Recall: 0.106697 - F1: 0.056589 - Time: 28.01
# INFO    | Line 141 | Validation Accuracy: 0.115731
# INFO    | Line 144 | Epoch No: 100 - Loss: 0.514837 - Training Accuracy: 0.118750 - Validation Accuracy: 0.115731
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Training phase and store the model based on loss and accuracy
#
# The number of model store based on variable MAX_SAVED_MODEL

# %%
# def memory_is_low():
#     """Check if memory is low. You can implement your own logic here."""
#     # Placeholder logic; replace with actual memory checking
#     import psutil
#     return psutil.virtual_memory().available < (100 * 1024 * 1024)  # Less than 100 MB

# def find_worst_model_by_accuracy(saved_models):
#     worst_model = None
#     worst_accuracy = float('inf')
#     for model_info in saved_models:
#         if model_info['accuracy'] < worst_accuracy:
#             worst_accuracy = model_info['accuracy']
#             worst_model = model_info
#     if worst_model:
#         print_log(f"Worst model - Path: {worst_model['path']}, Accuracy: {worst_model['accuracy']:.6f}, Loss: {worst_model['loss']:.6f}")
#     if worst_model:
#         if os.path.exists(worst_model['path']):
#             os.remove(worst_model['path'])
#             print_log(f"Deleted worst model by less accuracy: {worst_model['path']} with Accuracy: {worst_model['accuracy']:.6f}, Loss: {worst_model['loss']:.6f}")
#         saved_models.remove(worst_model)

# def find_worst_model_by_loss(saved_models):
#     worst_model = None
#     worst_loss = float('-inf')
#     for model_info in saved_models:
#         if model_info['loss'] > worst_loss:
#             worst_loss = model_info['loss']
#             worst_model = model_info
#     if worst_model:
#         print_log(f"Worst model - Path: {worst_model['path']}, Accuracy: {worst_model['accuracy']:.6f}, Loss: {worst_model['loss']:.6f}")
#     if worst_model:
#         if os.path.exists(worst_model['path']):
#             os.remove(worst_model['path'])
#             print_log(f"Deleted worst model by higher loss: {worst_model['path']} with Accuracy: {worst_model['accuracy']:.6f}, Loss: {worst_model['loss']:.6f}")
#         saved_models.remove(worst_model)

# def find_worst_model_by_combined_metric(saved_models, weight_loss=0.5, weight_accuracy=0.5):
#     worst_model = None
#     worst_combined_metric = float('-inf')
#     max_loss = max([model['loss'] for model in saved_models])
#     min_loss = min([model['loss'] for model in saved_models])
#     max_accuracy = max([model['accuracy'] for model in saved_models])
#     min_accuracy = min([model['accuracy'] for model in saved_models])
#     for model_info in saved_models:
#         normalized_loss = (model_info['loss'] - min_loss) / (max_loss - min_loss + 1e-8)
#         normalized_accuracy = (model_info['accuracy'] - min_accuracy) / (max_accuracy - min_accuracy + 1e-8)
#         combined_metric = (weight_loss * normalized_loss) - (weight_accuracy * normalized_accuracy)
#         if combined_metric > worst_combined_metric:
#             worst_combined_metric = combined_metric
#             worst_model = model_info
#     if worst_model:
#         print_log(f"Worst model - Path: {worst_model['path']}, Accuracy: {worst_model['accuracy']:.6f}, Loss: {worst_model['loss']:.6f}")
#     if worst_model:
#         if os.path.exists(worst_model['path']):
#             os.remove(worst_model['path'])
#             print_log(f"Deleted worst model by less accuracy and higher loss: {worst_model['path']} with Accuracy: {worst_model['accuracy']:.6f}, Loss: {worst_model['loss']:.6f}")
#         saved_models.remove(worst_model)



# # epochs=1
# for i in range(init_epoch, epochs):
#     print_log(f"Epoch - {i+1} is started")
# #     print(torch.cuda.memory_summary())
# #     pred_train = torch.tensor([], dtype=torch.long)
# #     label_train = torch.tensor([], dtype=torch.long)
# #     all_labels = torch.tensor([], dtype=torch.long)
# #     all_preds = torch.tensor([], dtype=torch.long)
#     t_loss = 0.0
#     start = time.time()
#     model.train(True)
    
#     # Training phase
#     for batch_idx, item in enumerate(dataloader):
#         anchor, positive, negative, anchor_class,negative_class = item
#         optimizer.zero_grad()
# #         print(len(anchor))
#         # Forward pass for triplet loss
#         anchor_class_scores,anchor_features= model(anchor.float())
#         positive_class_scores,positive_features = model(positive.float())
#         negative_class_scores,negative_features = model(negative.float())
# #         print(len(anchor_features),"anchor_features")
# #         feature_embeddings_train.append(anchor_features)
# #         feature_embeddings_train.append(positive_features)
# #         feature_embeddings_train.append(negative_features)
# #         post_enc_test.append(post_enc_anchor)
# #         post_enc_test.append(post_enc_positive)
# #         post_enc_test.append(post_enc_negative)
        
# #         print(len(feature_embeddings_train),"feature_embeddings_train")
#         # Compute triplet loss
#         triplet_loss = loss_fn(anchor_features, positive_features, negative_features)
# #         triplet_loss=0
#         # Forward pass for classification loss
# #         print(anchor_class,"anchor_class_scores")
# #         all_class_scores = torch.cat([anchor_class_scores, positive_class_scores, negative_class_scores], dim=0)
# #         all_labels_train = torch.cat([anchor_class, anchor_class, negative_class], dim=0)  # Assuming the third element is the label
# #         predicted_classes_train = torch.argmax(all_class_scores, dim=1)
# #         print(len(all_class_scores),"all_class_scores")
# #         pred_train.extend(predicted_classes_train)
# #         label_train.extend(all_labels_train)
# #         pred_train = torch.cat((pred_train, predicted_classes_train), dim=0)
# #         label_train = torch.cat((label_train, all_labels_train), dim=0)
# #         correct_predictions_train= (predicted_classes_train == all_labels)

# #         accuracy_train = correct_predictions_train.sum().item() / len(all_labels)
# #         print("accuracy of train", accuracy_train)
#         # Compute classification loss
#         #class_loss = classification_loss_fn(all_class_scores, all_labels_train)
        
#         # Combine losses
#         total_loss = triplet_loss #+ class_loss
# #         total_loss=class_loss
# #         print(class_loss,"class_loss",triplet_loss,"triplet_loss")
#         total_loss.backward()
#         optimizer.step()
        
#         t_loss += total_loss.item()
    
#     t_loss /= len(dataloader)
#     training_losses.append(t_loss)
    
# #     accuracy_train = accuracy_score(all_labels_train, predicted_classes_train)
# #     print("accuracy of train", accuracy_train)
#     # Validation phase
#     model.eval()
#     v_loss = 0.0
#     all_preds = []
#     all_labels = []
#     t_dataset = TestDataset(validation_data)
    
#     t_dataloader = DataLoader(t_dataset, batch_size=batch_size, shuffle=False)
#     tot = 0
#     print_log(f"The lenth of t_dataloader : {len(t_dataloader)}")
#     for batch_idx_t, item_t in enumerate(t_dataloader):
#         with torch.no_grad():
#             val = tot // 992
#             tot += 1
            
#             item_t_in,class_label=item_t
#             item_out = model(item_t_in.float())
#             class_scores = item_out[0]
# #             post_enc_val=item_out[2]
# #             post_enc_test.append(post_enc_val)
#             true_labels = class_label
#             predicted_classes = torch.argmax(class_scores, dim=1)
            
#             correct_predictions = (predicted_classes == true_labels)
            
#             accuracy = correct_predictions.sum().item() / len(true_labels)
            
# #             print(f"Batch {batch_idx_t} - True Labels: {true_labels.tolist()} - Predicted: {predicted_classes.tolist()} -Class Labels: {class_label}")
#             all_preds.extend(predicted_classes.tolist())
#             all_labels.extend(true_labels.tolist())
# #             val_loss = classification_loss_fn(class_scores, true_labels)
# #             v_loss += val_loss.item()
# #     v_loss /= len(t_dataloader)
# #     validation_losses.append(v_loss)
#     accuracy = accuracy_score(all_labels, all_preds)
#     precision = precision_score(all_labels, all_preds, average='macro')
#     recall = recall_score(all_labels, all_preds, average='macro')
#     f1 = f1_score(all_labels, all_preds, average='macro')
#     print_log(f"loop done  {tot}")
#     end = time.time()
    
#     print_log(f"------> Epoch No: {i+1} - Loss: {t_loss:.6f} - Accuracy: {accuracy:.6f} - Precision: {precision:.6f} - Recall: {recall:.6f} - F1: {f1:.6f} - Time: {end-start:.2f}")
# #     scheduler.step(t_loss)
    
#     # Check memory status
#     if memory_is_low():
#         print_log(f"Memory is running low, attempting to free up space by deleting the worst model.")
#         delete_worst_model(saved_models)

#     # Save model if validation loss improves
#     if t_loss < best_loss:
#         print_log(f"Loss improved from {best_loss:.6f} to {t_loss:.6f}. Saving model...")
#         best_loss = t_loss
#         model_path = f"{best_model_save_path}/epoch_{i+1}_accuracy_{accuracy:.6f}_loss_{t_loss:.6f}.pt"
#         torch.save(model, model_path)
#         print_log(f"Best model saved at (by loss): {model_path}")
#         saved_models.append({'path': model_path, 'loss': t_loss, 'accuracy' : accuracy})

#         if len(saved_models) > max_saved_models:
#             find_worst_model_by_loss(saved_models)
#             find_worst_model_by_accuracy(saved_models)
#             find_worst_model_by_combined_metric(saved_models)

#     # Save model if validation accuracy improves
#     if accuracy > best_accuracy:
#         print_log(f"Accuracy improved from {best_accuracy:.6f} to {accuracy:.6f}. Saving model...")
#         best_accuracy = accuracy
#         model_path = f"{best_model_save_path}/epoch_{i+1}_accuracy_{accuracy:.6f}_loss_{t_loss:.6f}.pt"
#         torch.save(model, model_path)
#         print_log(f"Best model saved at (by accuracy): {model_path}")
#         saved_models.append({'path': model_path, 'loss' : t_loss, 'accuracy': -accuracy})

#         if len(saved_models) > max_saved_models:
#             # find_worst_model_by_loss(saved_models)
#             # find_worst_model_by_accuracy(saved_models)
#             find_worst_model_by_combined_metric(saved_models)

# %% [markdown]
# # Get best model

# %%
directory = '/kaggle/working/best_models'

# Get the list of files in the directory
files = os.listdir(directory)

# Print the list of files
print_log(f"The model file directory : {directory}")
for file in files:
    print_log(f"file  :  {file}")

# Function to extract EER from filename
def extract_accuracy(filename):
    try:
        parts = filename.split('_')
        accuracy_index = parts.index('accuracy') + 1
        accuracy_value = float(parts[accuracy_index].replace('.pt', ''))
        return accuracy_value
    except (ValueError, IndexError):
        return float('inf')

# Find the file with the lowest EER
best_model_file = max(files, key=extract_accuracy)
best_acc = extract_accuracy(best_model_file)

# Load the best model
best_model_path = os.path.join(directory, best_model_file)
test_model = torch.load(best_model_path)

print_log(f"Best model: {best_model_file} with accuracy: {best_acc}")
print_log(f"Loaded model from: {best_model_path}")
# Out:
# INFO    | Line 7   | The model file directory : /kaggle/working/best_models
# INFO    | Line 9   | file  :  epoch_73accuracy0.08861190905107356.pt
# INFO    | Line 9   | file  :  epoch_49accuracy0.11543892107697551.pt
# INFO    | Line 9   | file  :  epoch_57accuracy0.09757047568041287.pt
# INFO    | Line 9   | file  :  epoch_79accuracy0.061882272749403576.pt
# /tmp/ipykernel_24/3462326453.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_model = torch.load(best_model_path)
# INFO    | Line 29  | Best model: epoch_73accuracy0.08861190905107356.pt with accuracy: inf
# INFO    | Line 30  | Loaded model from: /kaggle/working/best_models/epoch_73accuracy0.08861190905107356.pt

# %%
# Plotting training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.show()
print_log("Training loss over epoches polt is create sucessfully")
# Out:
# INFO    | Line 9   | Training loss over epoches polt is create sucessfully

# %%
# Plotting accuracy vs epochs
plt.figure(figsize=(10, 5))
plt.plot(training_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.show()

print_log("Accuracy vs Epochs plot created successfully")
# Out:
# INFO    | Line 11  | Accuracy vs Epochs plot created successfully

# %% [markdown]
# # Testing Phase

# %%
test_dataset = TestDataset(test_data)
test_dataloader = DataLoader(test_dataset, batch_size=2)
feature_embeddings = []
tot=0
all_preds_test = []
all_labels_test = []

# %%
tot=0
for batch_idx_t, item_t in enumerate(test_dataloader):
    with torch.no_grad():
        val=tot//162 ## this value needs to be changed based on the sequence from each activity
        tot+=1
        item_t_in,class_label=item_t
#         print("tot",tot)
        true_labels=class_label

        item_out = test_model(item_t_in.float())
        class_scores=item_out[0]
#         print(class_scores)
        feature_embeddings.append(item_out[1])
        predicted_classes = torch.argmax(class_scores, dim=1)
        all_preds_test.extend(predicted_classes.tolist())
        all_labels_test.extend(true_labels.tolist())

# %%
# Move each tensor to CPU, detach from computation graph, and convert to NumPy array
feature_embeddings_cpu = [emb.cpu().detach().numpy() for emb in feature_embeddings]

# Check for NaNs in individual arrays
for i, emb_np in enumerate(feature_embeddings_cpu):
    if np.isnan(emb_np).any():
        print(f"NaN detected in feature_embeddings_cpu at index {i}")

# Concatenate the list of numpy arrays into a single numpy array
feature_embeddings_np = np.concatenate(feature_embeddings_cpu, axis=0)

# Check for NaNs in the concatenated array
if np.isnan(feature_embeddings_np).any():
    print("NaN detected in feature_embeddings_np")

# Perform PCA to reduce dimensions to 2
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principal_components = pca.fit_transform(feature_embeddings_np)

# Check for NaNs in PCA results
if np.isnan(principal_components).any():
    print("NaN detected in principal_components")

# Plot PCA results
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(principal_components[:, 0], principal_components[:, 1], alpha=0.5)
plt.title('PCA of Feature Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
print_log("PCA of Feature embeddings polt is create sucessfully")
# Out:
# INFO    | Line 36  | PCA of Feature embeddings polt is create sucessfully

# %%
accuracy_test = accuracy_score(all_labels_test, all_preds_test)
precision_test = precision_score(all_labels_test, all_preds_test, average='macro')
recall_test = recall_score(all_labels_test, all_preds_test, average='macro')
f1_test = f1_score(all_labels_test, all_preds_test, average='macro')

print_log(f"Accuracy: {accuracy_test:.6f} - Precision: {precision_test:.6f} - Recall: {recall_test:.6f} - F1: {f1_test:.6f}")
# Out:
# INFO    | Line 6   | Accuracy: 0.102521 - Precision: 0.040834 - Recall: 0.095469 - F1: 0.046284
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf_matrix = confusion_matrix(all_labels_test, all_preds_test)

# Calculate the accuracy for each class
class_accuracies = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Print the accuracy for each class
for i, class_accuracy in enumerate(class_accuracies):
    print_log(f"Accuracy for class {i}: {class_accuracy:.6f}")


plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')
plt.show()
print_log("Confusion matrix is create sucessfully using test")
# Out:
# INFO    | Line 8   | Accuracy for class 0: 0.000000
# INFO    | Line 8   | Accuracy for class 1: 0.000000
# INFO    | Line 8   | Accuracy for class 2: 0.775835
# INFO    | Line 8   | Accuracy for class 3: 0.082617
# INFO    | Line 8   | Accuracy for class 4: 0.000000
# INFO    | Line 8   | Accuracy for class 5: 0.000771
# INFO    | Line 8   | Accuracy for class 6: 0.000000
# INFO    | Line 8   | Accuracy for class 7: 0.000000
# INFO    | Line 8   | Accuracy for class 8: 0.000000
# INFO    | Line 18  | Confusion matrix is create sucessfully using test

# %%
conf_matrix = confusion_matrix(all_labels, all_preds)

# Calculate the accuracy for each class
class_accuracies = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Print the accuracy for each class
for i, class_accuracy in enumerate(class_accuracies):
    print_log(f"Accuracy for class {i}: {class_accuracy:.6f}")

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')
plt.show()
print_log("Confusion matrix is create sucessfully")
# Out:
# INFO    | Line 8   | Accuracy for class 0: 0.000000
# INFO    | Line 8   | Accuracy for class 1: 0.000000
# INFO    | Line 8   | Accuracy for class 2: 0.708861
# INFO    | Line 8   | Accuracy for class 3: 0.250196
# INFO    | Line 8   | Accuracy for class 4: 0.000000
# INFO    | Line 8   | Accuracy for class 5: 0.001215
# INFO    | Line 8   | Accuracy for class 6: 0.000000
# INFO    | Line 8   | Accuracy for class 7: 0.000000
# INFO    | Line 8   | Accuracy for class 8: 0.000000
# INFO    | Line 17  | Confusion matrix is create sucessfully
